# %% [markdown]
# ## CS310 Natural Language Processing
# ## Assignment 2. Word2vec Implementation
#
# **Total points**: 50
#
# Train a word2vec model using the **skip-gram** architecture and **negative sampling**.
#
# You should roughtly follow the structure of the notebook. Add additional cells if you feel needed.
#
# You can (and you should) re-use the code from *Lab 4 (part 2): Data preparation for implementing word2vec*.
#
# Make sure your code is readable and well-structured.

# %% [markdown]
# ### 0. Import Necessary Libraries

# %%
from typing import List
from utils import CorpusReader
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import TruncatedSVD
from torch.utils.data import Dataset, DataLoader
import re
import itertools
from collections import Counter
import gensim

# %% [markdown]
# ### 1. Data Processing
#
# The corpus data is in `lunyu_20chapters.txt`. Use the `CorpusReader` class in `utils.py` to help you.

# %%
# Read raw data in lunyu_20chapters.txt

### YOUR CODE HERE ###
corpus = CorpusReader(inputFileName="lunyu_20chapters.txt", min_count=1)
print(corpus.word2id["子"])
print(corpus.id2word[1])
print(len(corpus.id2word))
### END YOUR CODE ###
# Out:
# Total vocabulary: 1352
# 1
# 子
# 1352

# %%
# Re-use the code from lab with necessary modifications

def generate_data(words: List[str], window_size: int, k: int, corpus: CorpusReader):
    """ Generate the training data for word2vec skip-gram model
    Args:
        text: the input text
        window_size: the size of the context window
        k: the number of negative samples
        corpus: the corpus object, providing utilities such as word2id, getNegatives, etc.
    """
    ### YOUR CODE HERE ###
    word_ids = [corpus.word2id[word] for word in words if word in corpus.word2id]  # Convert words to word IDs
    result=[]
    for i, center_word_id in enumerate(word_ids):
        start = max(0, i - window_size)
        end = min(len(word_ids), i + window_size + 1)
        outside_word_ids = [word_ids[j] for j in range(start, end) if j != i]
        for i in outside_word_ids:
            negative_samples = corpus.getNegatives(center_word_id, k)
            result.append((center_word_id,i,negative_samples))
    return result
    ### END YOUR CODE ###

def batchify(data: List, batch_size: int):
    """ Group a stream into batches and yield them as torch tensors.
    Args:
        data: a list of tuples
        batch_size: the batch size 
    Yields:
        a tuple of three torch tensors: center, outside, negative
    """
    assert batch_size < len(data) # data should be long enough
    result=[]
    for i in range(0, len(data), batch_size):
        batch = data[i:i + batch_size]
        if i > len(data) - batch_size: # if the last batch is smaller than batch_size, pad it with the first few data
            batch = batch + data[:i + batch_size - len(data)]
        
        ## YOUR CODE HERE ###
        
        center_ids = torch.tensor([item[0] for item in batch], dtype=torch.long)
        outside_ids = torch.tensor([item[1] for item in batch], dtype=torch.long)
        negative_ids = torch.tensor(np.vstack([item[2] for item in batch]), dtype=torch.long)

        result.append((center_ids, outside_ids, negative_ids))
    return result
        ### END YOUR CODE ###

# %% [markdown]
# ### 2. Build the Model

# %%
class SkipGram(nn.Module):
    def __init__(self, vocab_size, emb_size,word2id):
        super(SkipGram, self).__init__()
        self.vocab_size = vocab_size
        self.emb_size = emb_size
        self.emb_v = nn.Embedding(vocab_size, emb_size, sparse=True)
        self.emb_u = nn.Embedding(vocab_size, emb_size, sparse=True)
        self.word2id = word2id
        initrange = 1.0 / self.emb_size # some experience passed down from generation to generation
        nn.init.uniform_(self.emb_v.weight.data, -initrange, initrange) # same outcome as self.emb_v.weight.data.uniform_(-initrange, initrange)
        nn.init.constant_(self.emb_u.weight.data, 0) # same outcome as self.emb_u.weight.data.zero_()

    def forward(self, center, outside, negative):
        """
        Args:
            center: the center word indices (B, )
            outside: the outside word indices (B, )
            negative: the negative word indices (B, k)
        """
        v_c = self.emb_v(center)
        u_o = self.emb_u(outside)
        u_n = self.emb_u(negative)
        
        ### YOUR CODE HERE ###
        positive_dot_product = torch.mul(v_c, u_o).sum(dim=1)
        positive_score = F.logsigmoid(torch.clamp(positive_dot_product, min=-10, max=10))

        negative_dot_product = torch.bmm(u_n, v_c.unsqueeze(2)).squeeze(2)
        negative_score = F.logsigmoid(torch.clamp(-negative_dot_product, min=-10, max=10)).sum(dim=1)

        loss = -(positive_score + negative_score).mean()
        # Hint: torch.clamp the input to F.logsigmoid to avoid numerical underflow/overflow
        ### END YOUR CODE ###

        return loss
    
    def save_embedding(self, id2word, file_name):
        embedding = self.emb_v.weight.cpu().data.numpy()
        with open(file_name, 'w') as f:
            f.write('%d %d\n' % (len(id2word), self.emb_size))
            for wid, w in id2word.items():
                e = ' '.join(map(lambda x: str(x), embedding[wid]))
                f.write('%s %s\n' % (w, e))

# %% [markdown]
# ### 3. Train and Evaluate

# %%
def train(model, dataloader, optimizer,scheduler, epochs):
    # Write your own code for this train function
    # You don't need exactly the same arguments

    ### YOUR CODE HERE ###
    model.train()  # Set model to training mode
    device = torch.device("cpu")
    model.to(device)

    for epoch in range(epochs):
        total_loss = 0
        for i, (center, outside, negative) in enumerate(dataloader):
            center, outside, negative = center.to(device), outside.to(device), negative.to(device)
            
            optimizer.zero_grad()  # Reset gradients
            loss = model(center, outside, negative)
            loss.backward()  # Backpropagate
            
            # Optional: Clip gradients to avoid exploding gradients
            # torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=5)
            
            optimizer.step()  # Update weights
            
            total_loss += loss.item()
            
            if i % 10 == 0:  # Print average loss every 100 batches
                print(f'Epoch {epoch+1}, Batch {i+1}, Loss: {total_loss/(i+1):.4f}')
        
        # Optional: Adjust learning rate
        scheduler.step()

    # Save embeddings after training
    # model.save_embedding(corpus.id2word, 'trained_embeddings.txt')
    ### END YOUR CODE ###

def tokenize_text(file_path):
    """
    Tokenizes the text from the given file path into a list of words.
    Basic preprocessing includes lowercasing and removing non-alphanumeric characters.
    """
    with open(file_path, 'r', encoding='utf-8') as file:
        text = file.read().lower()  # Convert text to lowercase
        # Tokenize by splitting on non-alphanumeric characters
        tokens = re.split(r'\W+', text)
        # Remove empty tokens
        tokens = [token for token in tokens if token]
    return tokens

# Suggested hyperparameters
initial_lr = 0.001
batch_size = 16
emb_size = 50
window_size = 5
k = 10 # the number of negative samples, change with your own choice for better embedding performance
min_count = 1 # because our data is small. If min_count > 1, you should filter out those unknown words from the data in train() function
epochs=10

emb_sizes = [50, 100]
k_values = [5, 10, 15]
window_sizes = [1, 3, 5]
for emb_size, k, window_size in itertools.product(emb_sizes, k_values, window_sizes):
    print(f"------------------------embeddings_{emb_size}_{k}_{window_size}--------------------")
    model = SkipGram(len(corpus.word2id), emb_size,corpus.word2id)
    optimizer = torch.optim.SparseAdam(model.parameters(), lr=initial_lr) # or torch.optim.SparseAdam()
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs) # or torch.optim.lr_scheduler.StepLR()

    words = tokenize_text("lunyu_20chapters.txt")
    data = generate_data(words, window_size, k, corpus)
    print(len(data))
    dataloader = batchify(data,batch_size)

    train(model, dataloader, optimizer, scheduler,epochs)
    file_name = f"embeddings_{emb_size}_{k}_{window_size}.txt"
    model.save_embedding(corpus.id2word, file_name)

### Hints: ###
# - If you have cuda-supported GPUs, you can run the training faster by
#   `device = torch.device("cuda" if self.use_cuda else "cpu")`
#   `model.cuda()`
#   You also need to move all tensor data to the same device
# - If you find Inf or NaN in the loss, you can try to clip the gradient usning `torch.nn.utils.clip_grad_norm_`
# - Remember to save the embeddings when training is done
# Out:
# ------------------------embeddings_50_5_1--------------------
# 462
# Epoch 1, Batch 1, Loss: 4.1589
# Epoch 1, Batch 11, Loss: 4.1585
# Epoch 1, Batch 21, Loss: 4.1564
# Epoch 2, Batch 1, Loss: 4.1533
# Epoch 2, Batch 11, Loss: 4.1428
# Epoch 2, Batch 21, Loss: 4.1284
# Epoch 3, Batch 1, Loss: 4.1348
# Epoch 3, Batch 11, Loss: 4.0900
# Epoch 3, Batch 21, Loss: 4.0500
# Epoch 4, Batch 1, Loss: 4.0925
# Epoch 4, Batch 11, Loss: 3.9955
# Epoch 4, Batch 21, Loss: 3.9251
# Epoch 5, Batch 1, Loss: 4.0289
# Epoch 5, Batch 11, Loss: 3.8804
# Epoch 5, Batch 21, Loss: 3.7834
# Epoch 6, Batch 1, Loss: 3.9571
# Epoch 6, Batch 11, Loss: 3.7705
# Epoch 6, Batch 21, Loss: 3.6546
# Epoch 7, Batch 1, Loss: 3.8913
# Epoch 7, Batch 11, Loss: 3.6821
# Epoch 7, Batch 21, Loss: 3.5547
# Epoch 8, Batch 1, Loss: 3.8410
# Epoch 8, Batch 11, Loss: 3.6207
# Epoch 8, Batch 21, Loss: 3.4875
# Epoch 9, Batch 1, Loss: 3.8096
# Epoch 9, Batch 11, Loss: 3.5847
# Epoch 9, Batch 21, Loss: 3.4495
# Epoch 10, Batch 1, Loss: 3.7947
# Epoch 10, Batch 11, Loss: 3.5686
# Epoch 10, Batch 21, Loss: 3.4334
# ------------------------embeddings_50_5_3--------------------
# 1380
# Epoch 1, Batch 1, Loss: 4.1589
# Epoch 1, Batch 11, Loss: 4.1587
# Epoch 1, Batch 21, Loss: 4.1577
# Epoch 1, Batch 31, Loss: 4.1573
# Epoch 1, Batch 41, Loss: 4.1547
# Epoch 1, Batch 51, Loss: 4.1470
# Epoch 1, Batch 61, Loss: 4.1407
# Epoch 1, Batch 71, Loss: 4.1405
# Epoch 1, Batch 81, Loss: 4.1322
# Epoch 2, Batch 1, Loss: 4.1541
# Epoch 2, Batch 11, Loss: 4.0634
# Epoch 2, Batch 21, Loss: 3.9967
# Epoch 2, Batch 31, Loss: 4.0131
# Epoch 2, Batch 41, Loss: 3.9809
# Epoch 2, Batch 51, Loss: 3.9034
# Epoch 2, Batch 61, Loss: 3.8735
# Epoch 2, Batch 71, Loss: 3.8896
# Epoch 2, Batch 81, Loss: 3.8623
# Epoch 3, Batch 1, Loss: 4.1289
# Epoch 3, Batch 11, Loss: 3.7528
# Epoch 3, Batch 21, Loss: 3.5500
# Epoch 3, Batch 31, Loss: 3.6267
# Epoch 3, Batch 41, Loss: 3.5761
# Epoch 3, Batch 51, Loss: 3.4291
# Epoch 3, Batch 61, Loss: 3.3993
# Epoch 3, Batch 71, Loss: 3.4497
# Epoch 3, Batch 81, Loss: 3.4257
# Epoch 4, Batch 1, Loss: 4.0665
# Epoch 4, Batch 11, Loss: 3.4503
# Epoch 4, Batch 21, Loss: 3.1648
# Epoch 4, Batch 31, Loss: 3.2869
# Epoch 4, Batch 41, Loss: 3.2368
# Epoch 4, Batch 51, Loss: 3.0550
# Epoch 4, Batch 61, Loss: 3.0322
# Epoch 4, Batch 71, Loss: 3.1040
# Epoch 4, Batch 81, Loss: 3.0872
# Epoch 5, Batch 1, Loss: 3.9755
# Epoch 5, Batch 11, Loss: 3.2245
# Epoch 5, Batch 21, Loss: 2.9055
# Epoch 5, Batch 31, Loss: 3.0507
# Epoch 5, Batch 41, Loss: 3.0047
# Epoch 5, Batch 51, Loss: 2.8053
# Epoch 5, Batch 61, Loss: 2.7866
# Epoch 5, Batch 71, Loss: 2.8677
# Epoch 5, Batch 81, Loss: 2.8555
# Epoch 6, Batch 1, Loss: 3.8753
# Epoch 6, Batch 11, Loss: 3.0587
# Epoch 6, Batch 21, Loss: 2.7284
# Epoch 6, Batch 31, Loss: 2.8858
# Epoch 6, Batch 41, Loss: 2.8438
# Epoch 6, Batch 51, Loss: 2.6359
# Epoch 6, Batch 61, Loss: 2.6196
# Epoch 6, Batch 71, Loss: 2.7045
# Epoch 6, Batch 81, Loss: 2.6953
# Epoch 7, Batch 1, Loss: 3.7839
# Epoch 7, Batch 11, Loss: 2.9410
# Epoch 7, Batch 21, Loss: 2.6084
# Epoch 7, Batch 31, Loss: 2.7724
# Epoch 7, Batch 41, Loss: 2.7337
# Epoch 7, Batch 51, Loss: 2.5220
# Epoch 7, Batch 61, Loss: 2.5076
# Epoch 7, Batch 71, Loss: 2.5940
# Epoch 7, Batch 81, Loss: 2.5871
# Epoch 8, Batch 1, Loss: 3.7133
# Epoch 8, Batch 11, Loss: 2.8633
# Epoch 8, Batch 21, Loss: 2.5315
# Epoch 8, Batch 31, Loss: 2.6991
# Epoch 8, Batch 41, Loss: 2.6627
# Epoch 8, Batch 51, Loss: 2.4500
# Epoch 8, Batch 61, Loss: 2.4369
# Epoch 8, Batch 71, Loss: 2.5241
# Epoch 8, Batch 81, Loss: 2.5188
# Epoch 9, Batch 1, Loss: 3.6684
# Epoch 9, Batch 11, Loss: 2.8183
# Epoch 9, Batch 21, Loss: 2.4876
# Epoch 9, Batch 31, Loss: 2.6573
# Epoch 9, Batch 41, Loss: 2.6224
# Epoch 9, Batch 51, Loss: 2.4096
# Epoch 9, Batch 61, Loss: 2.3977
# Epoch 9, Batch 71, Loss: 2.4854
# Epoch 9, Batch 81, Loss: 2.4813
# Epoch 10, Batch 1, Loss: 3.6468
# Epoch 10, Batch 11, Loss: 2.7979
# Epoch 10, Batch 21, Loss: 2.4680
# Epoch 10, Batch 31, Loss: 2.6387
# Epoch 10, Batch 41, Loss: 2.6046
# Epoch 10, Batch 51, Loss: 2.3921
# Epoch 10, Batch 61, Loss: 2.3808
# Epoch 10, Batch 71, Loss: 2.4690
# Epoch 10, Batch 81, Loss: 2.4655
# ------------------------embeddings_50_5_5--------------------
# 2290
# Epoch 1, Batch 1, Loss: 4.1589
# Epoch 1, Batch 11, Loss: 4.1588
# Epoch 1, Batch 21, Loss: 4.1582
# Epoch 1, Batch 31, Loss: 4.1569
# Epoch 1, Batch 41, Loss: 4.1559
# Epoch 1, Batch 51, Loss: 4.1556
# Epoch 1, Batch 61, Loss: 4.1539
# Epoch 1, Batch 71, Loss: 4.1472
# Epoch 1, Batch 81, Loss: 4.1342
# Epoch 1, Batch 91, Loss: 4.1215
# Epoch 1, Batch 101, Loss: 4.1053
# Epoch 1, Batch 111, Loss: 4.1006
# Epoch 1, Batch 121, Loss: 4.0994
# Epoch 1, Batch 131, Loss: 4.0922
# Epoch 1, Batch 141, Loss: 4.0689
# Epoch 2, Batch 1, Loss: 4.1447
# Epoch 2, Batch 11, Loss: 4.0538
# Epoch 2, Batch 21, Loss: 3.8372
# Epoch 2, Batch 31, Loss: 3.7415
# Epoch 2, Batch 41, Loss: 3.7447
# Epoch 2, Batch 51, Loss: 3.7893
# Epoch 2, Batch 61, Loss: 3.7846
# Epoch 2, Batch 71, Loss: 3.7065
# Epoch 2, Batch 81, Loss: 3.6050
# Epoch 2, Batch 91, Loss: 3.5501
# Epoch 2, Batch 101, Loss: 3.5003
# Epoch 2, Batch 111, Loss: 3.5083
# Epoch 2, Batch 121, Loss: 3.5297
# Epoch 2, Batch 131, Loss: 3.5292
# Epoch 2, Batch 141, Loss: 3.4824
# Epoch 3, Batch 1, Loss: 4.0669
# Epoch 3, Batch 11, Loss: 3.7676
# Epoch 3, Batch 21, Loss: 3.2563
# Epoch 3, Batch 31, Loss: 3.0995
# Epoch 3, Batch 41, Loss: 3.1326
# Epoch 3, Batch 51, Loss: 3.2469
# Epoch 3, Batch 61, Loss: 3.2620
# Epoch 3, Batch 71, Loss: 3.1538
# Epoch 3, Batch 81, Loss: 3.0188
# Epoch 3, Batch 91, Loss: 2.9644
# Epoch 3, Batch 101, Loss: 2.9179
# Epoch 3, Batch 111, Loss: 2.9448
# Epoch 3, Batch 121, Loss: 2.9862
# Epoch 3, Batch 131, Loss: 3.0005
# Epoch 3, Batch 141, Loss: 2.9575
# Epoch 4, Batch 1, Loss: 3.9140
# Epoch 4, Batch 11, Loss: 3.4929
# Epoch 4, Batch 21, Loss: 2.8807
# Epoch 4, Batch 31, Loss: 2.7211
# Epoch 4, Batch 41, Loss: 2.7660
# Epoch 4, Batch 51, Loss: 2.9099
# Epoch 4, Batch 61, Loss: 2.9374
# Epoch 4, Batch 71, Loss: 2.8176
# Epoch 4, Batch 81, Loss: 2.6727
# Epoch 4, Batch 91, Loss: 2.6218
# Epoch 4, Batch 101, Loss: 2.5768
# Epoch 4, Batch 111, Loss: 2.6080
# Epoch 4, Batch 121, Loss: 2.6535
# Epoch 4, Batch 131, Loss: 2.6737
# Epoch 4, Batch 141, Loss: 2.6330
# Epoch 5, Batch 1, Loss: 3.7209
# Epoch 5, Batch 11, Loss: 3.2556
# Epoch 5, Batch 21, Loss: 2.6170
# Epoch 5, Batch 31, Loss: 2.4689
# Epoch 5, Batch 41, Loss: 2.5179
# Epoch 5, Batch 51, Loss: 2.6732
# Epoch 5, Batch 61, Loss: 2.7097
# Epoch 5, Batch 71, Loss: 2.5851
# Epoch 5, Batch 81, Loss: 2.4399
# Epoch 5, Batch 91, Loss: 2.3926
# Epoch 5, Batch 101, Loss: 2.3489
# Epoch 5, Batch 111, Loss: 2.3795
# Epoch 5, Batch 121, Loss: 2.4240
# Epoch 5, Batch 131, Loss: 2.4468
# Epoch 5, Batch 141, Loss: 2.4081
# Epoch 6, Batch 1, Loss: 3.5282
# Epoch 6, Batch 11, Loss: 3.0639
# Epoch 6, Batch 21, Loss: 2.4276
# Epoch 6, Batch 31, Loss: 2.2929
# Epoch 6, Batch 41, Loss: 2.3425
# Epoch 6, Batch 51, Loss: 2.5013
# Epoch 6, Batch 61, Loss: 2.5439
# Epoch 6, Batch 71, Loss: 2.4181
# Epoch 6, Batch 81, Loss: 2.2764
# Epoch 6, Batch 91, Loss: 2.2325
# Epoch 6, Batch 101, Loss: 2.1900
# Epoch 6, Batch 111, Loss: 2.2189
# Epoch 6, Batch 121, Loss: 2.2614
# Epoch 6, Batch 131, Loss: 2.2855
# Epoch 6, Batch 141, Loss: 2.2487
# Epoch 7, Batch 1, Loss: 3.3665
# Epoch 7, Batch 11, Loss: 2.9210
# Epoch 7, Batch 21, Loss: 2.2960
# Epoch 7, Batch 31, Loss: 2.1722
# Epoch 7, Batch 41, Loss: 2.2211
# Epoch 7, Batch 51, Loss: 2.3803
# Epoch 7, Batch 61, Loss: 2.4268
# Epoch 7, Batch 71, Loss: 2.3014
# Epoch 7, Batch 81, Loss: 2.1637
# Epoch 7, Batch 91, Loss: 2.1226
# Epoch 7, Batch 101, Loss: 2.0813
# Epoch 7, Batch 111, Loss: 2.1089
# Epoch 7, Batch 121, Loss: 2.1498
# Epoch 7, Batch 131, Loss: 2.1747
# Epoch 7, Batch 141, Loss: 2.1396
# Epoch 8, Batch 1, Loss: 3.2504
# Epoch 8, Batch 11, Loss: 2.8248
# Epoch 8, Batch 21, Loss: 2.2109
# Epoch 8, Batch 31, Loss: 2.0945
# Epoch 8, Batch 41, Loss: 2.1428
# Epoch 8, Batch 51, Loss: 2.3015
# Epoch 8, Batch 61, Loss: 2.3504
# Epoch 8, Batch 71, Loss: 2.2260
# Epoch 8, Batch 81, Loss: 2.0915
# Epoch 8, Batch 91, Loss: 2.0523
# Epoch 8, Batch 101, Loss: 2.0122
# Epoch 8, Batch 111, Loss: 2.0390
# Epoch 8, Batch 121, Loss: 2.0789
# Epoch 8, Batch 131, Loss: 2.1044
# Epoch 8, Batch 141, Loss: 2.0707
# Epoch 9, Batch 1, Loss: 3.1804
# Epoch 9, Batch 11, Loss: 2.7691
# Epoch 9, Batch 21, Loss: 2.1626
# Epoch 9, Batch 31, Loss: 2.0503
# Epoch 9, Batch 41, Loss: 2.0983
# Epoch 9, Batch 51, Loss: 2.2567
# Epoch 9, Batch 61, Loss: 2.3069
# Epoch 9, Batch 71, Loss: 2.1834
# Epoch 9, Batch 81, Loss: 2.0509
# Epoch 9, Batch 91, Loss: 2.0130
# Epoch 9, Batch 101, Loss: 1.9737
# Epoch 9, Batch 111, Loss: 2.0003
# Epoch 9, Batch 121, Loss: 2.0398
# Epoch 9, Batch 131, Loss: 2.0657
# Epoch 9, Batch 141, Loss: 2.0329
# Epoch 10, Batch 1, Loss: 3.1481
# Epoch 10, Batch 11, Loss: 2.7440
# Epoch 10, Batch 21, Loss: 2.1411
# Epoch 10, Batch 31, Loss: 2.0306
# Epoch 10, Batch 41, Loss: 2.0785
# Epoch 10, Batch 51, Loss: 2.2369
# Epoch 10, Batch 61, Loss: 2.2877
# Epoch 10, Batch 71, Loss: 2.1647
# Epoch 10, Batch 81, Loss: 2.0332
# Epoch 10, Batch 91, Loss: 1.9959
# Epoch 10, Batch 101, Loss: 1.9572
# Epoch 10, Batch 111, Loss: 1.9838
# Epoch 10, Batch 121, Loss: 2.0233
# Epoch 10, Batch 131, Loss: 2.0494
# Epoch 10, Batch 141, Loss: 2.0171
# ------------------------embeddings_50_10_1--------------------
# 462
# Epoch 1, Batch 1, Loss: 7.6246
# Epoch 1, Batch 11, Loss: 7.6238
# Epoch 1, Batch 21, Loss: 7.6194
# Epoch 2, Batch 1, Loss: 7.6103
# Epoch 2, Batch 11, Loss: 7.5916
# Epoch 2, Batch 21, Loss: 7.5591
# Epoch 3, Batch 1, Loss: 7.5584
# Epoch 3, Batch 11, Loss: 7.4789
# Epoch 3, Batch 21, Loss: 7.3867
# Epoch 4, Batch 1, Loss: 7.4428
# Epoch 4, Batch 11, Loss: 7.2751
# Epoch 4, Batch 21, Loss: 7.1115
# Epoch 5, Batch 1, Loss: 7.2740
# Epoch 5, Batch 11, Loss: 7.0272
# Epoch 5, Batch 21, Loss: 6.8021
# Epoch 6, Batch 1, Loss: 7.0876
# Epoch 6, Batch 11, Loss: 6.7917
# Epoch 6, Batch 21, Loss: 6.5240
# Epoch 7, Batch 1, Loss: 6.9195
# Epoch 7, Batch 11, Loss: 6.6032
# Epoch 7, Batch 21, Loss: 6.3109
# Epoch 8, Batch 1, Loss: 6.7927
# Epoch 8, Batch 11, Loss: 6.4729
# Epoch 8, Batch 21, Loss: 6.1688
# Epoch 9, Batch 1, Loss: 6.7137
# Epoch 9, Batch 11, Loss: 6.3968
# Epoch 9, Batch 21, Loss: 6.0891
# Epoch 10, Batch 1, Loss: 6.6765
# Epoch 10, Batch 11, Loss: 6.3628
# Epoch 10, Batch 21, Loss: 6.0556
# ------------------------embeddings_50_10_3--------------------
# 1380
# Epoch 1, Batch 1, Loss: 7.6246
# Epoch 1, Batch 11, Loss: 7.6241
# Epoch 1, Batch 21, Loss: 7.6218
# Epoch 1, Batch 31, Loss: 7.6205
# Epoch 1, Batch 41, Loss: 7.6152
# Epoch 1, Batch 51, Loss: 7.5986
# Epoch 1, Batch 61, Loss: 7.5839
# Epoch 1, Batch 71, Loss: 7.5823
# Epoch 1, Batch 81, Loss: 7.5650
# Epoch 2, Batch 1, Loss: 7.5965
# Epoch 2, Batch 11, Loss: 7.4042
# Epoch 2, Batch 21, Loss: 7.2544
# Epoch 2, Batch 31, Loss: 7.2832
# Epoch 2, Batch 41, Loss: 7.2168
# Epoch 2, Batch 51, Loss: 7.0430
# Epoch 2, Batch 61, Loss: 6.9681
# Epoch 2, Batch 71, Loss: 6.9997
# Epoch 2, Batch 81, Loss: 6.9481
# Epoch 3, Batch 1, Loss: 7.5004
# Epoch 3, Batch 11, Loss: 6.7098
# Epoch 3, Batch 21, Loss: 6.2637
# Epoch 3, Batch 31, Loss: 6.4160
# Epoch 3, Batch 41, Loss: 6.3170
# Epoch 3, Batch 51, Loss: 5.9951
# Epoch 3, Batch 61, Loss: 5.9150
# Epoch 3, Batch 71, Loss: 6.0220
# Epoch 3, Batch 81, Loss: 5.9859
# Epoch 4, Batch 1, Loss: 7.3178
# Epoch 4, Batch 11, Loss: 6.0787
# Epoch 4, Batch 21, Loss: 5.4715
# Epoch 4, Batch 31, Loss: 5.7117
# Epoch 4, Batch 41, Loss: 5.6130
# Epoch 4, Batch 51, Loss: 5.2239
# Epoch 4, Batch 61, Loss: 5.1563
# Epoch 4, Batch 71, Loss: 5.3047
# Epoch 4, Batch 81, Loss: 5.2856
# Epoch 5, Batch 1, Loss: 7.0809
# Epoch 5, Batch 11, Loss: 5.6263
# Epoch 5, Batch 21, Loss: 4.9673
# Epoch 5, Batch 31, Loss: 5.2467
# Epoch 5, Batch 41, Loss: 5.1523
# Epoch 5, Batch 51, Loss: 4.7351
# Epoch 5, Batch 61, Loss: 4.6758
# Epoch 5, Batch 71, Loss: 4.8372
# Epoch 5, Batch 81, Loss: 4.8268
# Epoch 6, Batch 1, Loss: 6.8330
# Epoch 6, Batch 11, Loss: 5.2985
# Epoch 6, Batch 21, Loss: 4.6311
# Epoch 6, Batch 31, Loss: 4.9275
# Epoch 6, Batch 41, Loss: 4.8376
# Epoch 6, Batch 51, Loss: 4.4113
# Epoch 6, Batch 61, Loss: 4.3579
# Epoch 6, Batch 71, Loss: 4.5212
# Epoch 6, Batch 81, Loss: 4.5160
# Epoch 7, Batch 1, Loss: 6.6128
# Epoch 7, Batch 11, Loss: 5.0663
# Epoch 7, Batch 21, Loss: 4.4051
# Epoch 7, Batch 31, Loss: 4.7085
# Epoch 7, Batch 41, Loss: 4.6227
# Epoch 7, Batch 51, Loss: 4.1959
# Epoch 7, Batch 61, Loss: 4.1470
# Epoch 7, Batch 71, Loss: 4.3091
# Epoch 7, Batch 81, Loss: 4.3075
# Epoch 8, Batch 1, Loss: 6.4455
# Epoch 8, Batch 11, Loss: 4.9128
# Epoch 8, Batch 21, Loss: 4.2603
# Epoch 8, Batch 31, Loss: 4.5668
# Epoch 8, Batch 41, Loss: 4.4843
# Epoch 8, Batch 51, Loss: 4.0598
# Epoch 8, Batch 61, Loss: 4.0144
# Epoch 8, Batch 71, Loss: 4.1752
# Epoch 8, Batch 81, Loss: 4.1764
# Epoch 9, Batch 1, Loss: 6.3398
# Epoch 9, Batch 11, Loss: 4.8236
# Epoch 9, Batch 21, Loss: 4.1778
# Epoch 9, Batch 31, Loss: 4.4858
# Epoch 9, Batch 41, Loss: 4.4056
# Epoch 9, Batch 51, Loss: 3.9838
# Epoch 9, Batch 61, Loss: 3.9408
# Epoch 9, Batch 71, Loss: 4.1012
# Epoch 9, Batch 81, Loss: 4.1043
# Epoch 10, Batch 1, Loss: 6.2893
# Epoch 10, Batch 11, Loss: 4.7830
# Epoch 10, Batch 21, Loss: 4.1407
# Epoch 10, Batch 31, Loss: 4.4496
# Epoch 10, Batch 41, Loss: 4.3708
# Epoch 10, Batch 51, Loss: 3.9507
# Epoch 10, Batch 61, Loss: 3.9092
# Epoch 10, Batch 71, Loss: 4.0697
# Epoch 10, Batch 81, Loss: 4.0741
# ------------------------embeddings_50_10_5--------------------
# 2290
# Epoch 1, Batch 1, Loss: 7.6246
# Epoch 1, Batch 11, Loss: 7.6244
# Epoch 1, Batch 21, Loss: 7.6229
# Epoch 1, Batch 31, Loss: 7.6196
# Epoch 1, Batch 41, Loss: 7.6165
# Epoch 1, Batch 51, Loss: 7.6160
# Epoch 1, Batch 61, Loss: 7.6110
# Epoch 1, Batch 71, Loss: 7.5951
# Epoch 1, Batch 81, Loss: 7.5642
# Epoch 1, Batch 91, Loss: 7.5379
# Epoch 1, Batch 101, Loss: 7.5024
# Epoch 1, Batch 111, Loss: 7.4884
# Epoch 1, Batch 121, Loss: 7.4809
# Epoch 1, Batch 131, Loss: 7.4625
# Epoch 1, Batch 141, Loss: 7.4118
# Epoch 2, Batch 1, Loss: 7.5677
# Epoch 2, Batch 11, Loss: 7.3521
# Epoch 2, Batch 21, Loss: 6.8403
# Epoch 2, Batch 31, Loss: 6.6507
# Epoch 2, Batch 41, Loss: 6.6516
# Epoch 2, Batch 51, Loss: 6.7639
# Epoch 2, Batch 61, Loss: 6.7443
# Epoch 2, Batch 71, Loss: 6.5717
# Epoch 2, Batch 81, Loss: 6.3477
# Epoch 2, Batch 91, Loss: 6.2437
# Epoch 2, Batch 101, Loss: 6.1452
# Epoch 2, Batch 111, Loss: 6.1572
# Epoch 2, Batch 121, Loss: 6.1928
# Epoch 2, Batch 131, Loss: 6.1903
# Epoch 2, Batch 141, Loss: 6.0979
# Epoch 3, Batch 1, Loss: 7.3358
# Epoch 3, Batch 11, Loss: 6.7175
# Epoch 3, Batch 21, Loss: 5.5825
# Epoch 3, Batch 31, Loss: 5.2896
# Epoch 3, Batch 41, Loss: 5.3647
# Epoch 3, Batch 51, Loss: 5.6176
# Epoch 3, Batch 61, Loss: 5.6503
# Epoch 3, Batch 71, Loss: 5.4206
# Epoch 3, Batch 81, Loss: 5.1374
# Epoch 3, Batch 91, Loss: 5.0380
# Epoch 3, Batch 101, Loss: 4.9549
# Epoch 3, Batch 111, Loss: 5.0052
# Epoch 3, Batch 121, Loss: 5.0778
# Epoch 3, Batch 131, Loss: 5.1066
# Epoch 3, Batch 141, Loss: 5.0254
# Epoch 4, Batch 1, Loss: 6.9398
# Epoch 4, Batch 11, Loss: 6.1588
# Epoch 4, Batch 21, Loss: 4.8563
# Epoch 4, Batch 31, Loss: 4.5737
# Epoch 4, Batch 41, Loss: 4.6741
# Epoch 4, Batch 51, Loss: 4.9667
# Epoch 4, Batch 61, Loss: 5.0314
# Epoch 4, Batch 71, Loss: 4.7865
# Epoch 4, Batch 81, Loss: 4.4924
# Epoch 4, Batch 91, Loss: 4.3994
# Epoch 4, Batch 101, Loss: 4.3238
# Epoch 4, Batch 111, Loss: 4.3781
# Epoch 4, Batch 121, Loss: 4.4525
# Epoch 4, Batch 131, Loss: 4.4912
# Epoch 4, Batch 141, Loss: 4.4152
# Epoch 5, Batch 1, Loss: 6.4682
# Epoch 5, Batch 11, Loss: 5.6856
# Epoch 5, Batch 21, Loss: 4.3703
# Epoch 5, Batch 31, Loss: 4.1224
# Epoch 5, Batch 41, Loss: 4.2279
# Epoch 5, Batch 51, Loss: 4.5261
# Epoch 5, Batch 61, Loss: 4.6102
# Epoch 5, Batch 71, Loss: 4.3635
# Epoch 5, Batch 81, Loss: 4.0751
# Epoch 5, Batch 91, Loss: 3.9885
# Epoch 5, Batch 101, Loss: 3.9178
# Epoch 5, Batch 111, Loss: 3.9663
# Epoch 5, Batch 121, Loss: 4.0340
# Epoch 5, Batch 131, Loss: 4.0760
# Epoch 5, Batch 141, Loss: 4.0042
# Epoch 6, Batch 1, Loss: 6.0136
# Epoch 6, Batch 11, Loss: 5.2999
# Epoch 6, Batch 21, Loss: 4.0224
# Epoch 6, Batch 31, Loss: 3.8093
# Epoch 6, Batch 41, Loss: 3.9129
# Epoch 6, Batch 51, Loss: 4.2052
# Epoch 6, Batch 61, Loss: 4.3014
# Epoch 6, Batch 71, Loss: 4.0583
# Epoch 6, Batch 81, Loss: 3.7810
# Epoch 6, Batch 91, Loss: 3.7002
# Epoch 6, Batch 101, Loss: 3.6338
# Epoch 6, Batch 111, Loss: 3.6758
# Epoch 6, Batch 121, Loss: 3.7367
# Epoch 6, Batch 131, Loss: 3.7801
# Epoch 6, Batch 141, Loss: 3.7122
# Epoch 7, Batch 1, Loss: 5.6419
# Epoch 7, Batch 11, Loss: 5.0081
# Epoch 7, Batch 21, Loss: 3.7778
# Epoch 7, Batch 31, Loss: 3.5917
# Epoch 7, Batch 41, Loss: 3.6922
# Epoch 7, Batch 51, Loss: 3.9766
# Epoch 7, Batch 61, Loss: 4.0800
# Epoch 7, Batch 71, Loss: 3.8420
# Epoch 7, Batch 81, Loss: 3.5757
# Epoch 7, Batch 91, Loss: 3.4996
# Epoch 7, Batch 101, Loss: 3.4370
# Epoch 7, Batch 111, Loss: 3.4743
# Epoch 7, Batch 121, Loss: 3.5306
# Epoch 7, Batch 131, Loss: 3.5748
# Epoch 7, Batch 141, Loss: 3.5106
# Epoch 8, Batch 1, Loss: 5.3804
# Epoch 8, Batch 11, Loss: 4.8099
# Epoch 8, Batch 21, Loss: 3.6183
# Epoch 8, Batch 31, Loss: 3.4501
# Epoch 8, Batch 41, Loss: 3.5483
# Epoch 8, Batch 51, Loss: 3.8264
# Epoch 8, Batch 61, Loss: 3.9338
# Epoch 8, Batch 71, Loss: 3.7003
# Epoch 8, Batch 81, Loss: 3.4424
# Epoch 8, Batch 91, Loss: 3.3698
# Epoch 8, Batch 101, Loss: 3.3101
# Epoch 8, Batch 111, Loss: 3.3449
# Epoch 8, Batch 121, Loss: 3.3988
# Epoch 8, Batch 131, Loss: 3.4437
# Epoch 8, Batch 141, Loss: 3.3823
# Epoch 9, Batch 1, Loss: 5.2251
# Epoch 9, Batch 11, Loss: 4.6945
# Epoch 9, Batch 21, Loss: 3.5273
# Epoch 9, Batch 31, Loss: 3.3690
# Epoch 9, Batch 41, Loss: 3.4661
# Epoch 9, Batch 51, Loss: 3.7407
# Epoch 9, Batch 61, Loss: 3.8501
# Epoch 9, Batch 71, Loss: 3.6198
# Epoch 9, Batch 81, Loss: 3.3670
# Epoch 9, Batch 91, Loss: 3.2965
# Epoch 9, Batch 101, Loss: 3.2390
# Epoch 9, Batch 111, Loss: 3.2728
# Epoch 9, Batch 121, Loss: 3.3257
# Epoch 9, Batch 131, Loss: 3.3711
# Epoch 9, Batch 141, Loss: 3.3117
# Epoch 10, Batch 1, Loss: 5.1538
# Epoch 10, Batch 11, Loss: 4.6424
# Epoch 10, Batch 21, Loss: 3.4867
# Epoch 10, Batch 31, Loss: 3.3326
# Epoch 10, Batch 41, Loss: 3.4295
# Epoch 10, Batch 51, Loss: 3.7027
# Epoch 10, Batch 61, Loss: 3.8132
# Epoch 10, Batch 71, Loss: 3.5843
# Epoch 10, Batch 81, Loss: 3.3340
# Epoch 10, Batch 91, Loss: 3.2646
# Epoch 10, Batch 101, Loss: 3.2083
# Epoch 10, Batch 111, Loss: 3.2419
# Epoch 10, Batch 121, Loss: 3.2946
# Epoch 10, Batch 131, Loss: 3.3406
# Epoch 10, Batch 141, Loss: 3.2822
# ------------------------embeddings_50_15_1--------------------
# 462
# Epoch 1, Batch 1, Loss: 11.0904
# Epoch 1, Batch 11, Loss: 11.0885
# Epoch 1, Batch 21, Loss: 11.0810
# Epoch 2, Batch 1, Loss: 11.0626
# Epoch 2, Batch 11, Loss: 11.0280
# Epoch 2, Batch 21, Loss: 10.9764
# Epoch 3, Batch 1, Loss: 10.9707
# Epoch 3, Batch 11, Loss: 10.8291
# Epoch 3, Batch 21, Loss: 10.6896
# Epoch 4, Batch 1, Loss: 10.7782
# Epoch 4, Batch 11, Loss: 10.4811
# Epoch 4, Batch 21, Loss: 10.2398
# Epoch 5, Batch 1, Loss: 10.5100
# Epoch 5, Batch 11, Loss: 10.0664
# Epoch 5, Batch 21, Loss: 9.7397
# Epoch 6, Batch 1, Loss: 10.2262
# Epoch 6, Batch 11, Loss: 9.6808
# Epoch 6, Batch 21, Loss: 9.2964
# Epoch 7, Batch 1, Loss: 9.9800
# Epoch 7, Batch 11, Loss: 9.3786
# Epoch 7, Batch 21, Loss: 8.9613
# Epoch 8, Batch 1, Loss: 9.7994
# Epoch 8, Batch 11, Loss: 9.1728
# Epoch 8, Batch 21, Loss: 8.7405
# Epoch 9, Batch 1, Loss: 9.6890
# Epoch 9, Batch 11, Loss: 9.0539
# Epoch 9, Batch 21, Loss: 8.6175
# Epoch 10, Batch 1, Loss: 9.6377
# Epoch 10, Batch 11, Loss: 9.0011
# Epoch 10, Batch 21, Loss: 8.5659
# ------------------------embeddings_50_15_3--------------------
# 1380
# Epoch 1, Batch 1, Loss: 11.0904
# Epoch 1, Batch 11, Loss: 11.0899
# Epoch 1, Batch 21, Loss: 11.0867
# Epoch 1, Batch 31, Loss: 11.0848
# Epoch 1, Batch 41, Loss: 11.0762
# Epoch 1, Batch 51, Loss: 11.0499
# Epoch 1, Batch 61, Loss: 11.0267
# Epoch 1, Batch 71, Loss: 11.0219
# Epoch 1, Batch 81, Loss: 10.9919
# Epoch 2, Batch 1, Loss: 11.0643
# Epoch 2, Batch 11, Loss: 10.7445
# Epoch 2, Batch 21, Loss: 10.5107
# Epoch 2, Batch 31, Loss: 10.5490
# Epoch 2, Batch 41, Loss: 10.4371
# Epoch 2, Batch 51, Loss: 10.1566
# Epoch 2, Batch 61, Loss: 10.0369
# Epoch 2, Batch 71, Loss: 10.0751
# Epoch 2, Batch 81, Loss: 9.9815
# Epoch 3, Batch 1, Loss: 10.9230
# Epoch 3, Batch 11, Loss: 9.6207
# Epoch 3, Batch 21, Loss: 8.9314
# Epoch 3, Batch 31, Loss: 9.1563
# Epoch 3, Batch 41, Loss: 8.9890
# Epoch 3, Batch 51, Loss: 8.4779
# Epoch 3, Batch 61, Loss: 8.3556
# Epoch 3, Batch 71, Loss: 8.5048
# Epoch 3, Batch 81, Loss: 8.4365
# Epoch 4, Batch 1, Loss: 10.6203
# Epoch 4, Batch 11, Loss: 8.5921
# Epoch 4, Batch 21, Loss: 7.6842
# Epoch 4, Batch 31, Loss: 8.0441
# Epoch 4, Batch 41, Loss: 7.8840
# Epoch 4, Batch 51, Loss: 7.2799
# Epoch 4, Batch 61, Loss: 7.1842
# Epoch 4, Batch 71, Loss: 7.3901
# Epoch 4, Batch 81, Loss: 7.3537
# Epoch 5, Batch 1, Loss: 10.2145
# Epoch 5, Batch 11, Loss: 7.8601
# Epoch 5, Batch 21, Loss: 6.9086
# Epoch 5, Batch 31, Loss: 7.3250
# Epoch 5, Batch 41, Loss: 7.1805
# Epoch 5, Batch 51, Loss: 6.5452
# Epoch 5, Batch 61, Loss: 6.4676
# Epoch 5, Batch 71, Loss: 6.6861
# Epoch 5, Batch 81, Loss: 6.6680
# Epoch 6, Batch 1, Loss: 9.7870
# Epoch 6, Batch 11, Loss: 7.3336
# Epoch 6, Batch 21, Loss: 6.4001
# Epoch 6, Batch 31, Loss: 6.8373
# Epoch 6, Batch 41, Loss: 6.7077
# Epoch 6, Batch 51, Loss: 6.0680
# Epoch 6, Batch 61, Loss: 6.0031
# Epoch 6, Batch 71, Loss: 6.2187
# Epoch 6, Batch 81, Loss: 6.2120
# Epoch 7, Batch 1, Loss: 9.4074
# Epoch 7, Batch 11, Loss: 6.9617
# Epoch 7, Batch 21, Loss: 6.0600
# Epoch 7, Batch 31, Loss: 6.5039
# Epoch 7, Batch 41, Loss: 6.3866
# Epoch 7, Batch 51, Loss: 5.7531
# Epoch 7, Batch 61, Loss: 5.6974
# Epoch 7, Batch 71, Loss: 5.9072
# Epoch 7, Batch 81, Loss: 5.9082
# Epoch 8, Batch 1, Loss: 9.1197
# Epoch 8, Batch 11, Loss: 6.7159
# Epoch 8, Batch 21, Loss: 5.8422
# Epoch 8, Batch 31, Loss: 6.2879
# Epoch 8, Batch 41, Loss: 6.1797
# Epoch 8, Batch 51, Loss: 5.5544
# Epoch 8, Batch 61, Loss: 5.5053
# Epoch 8, Batch 71, Loss: 5.7108
# Epoch 8, Batch 81, Loss: 5.7172
# Epoch 9, Batch 1, Loss: 8.9383
# Epoch 9, Batch 11, Loss: 6.5730
# Epoch 9, Batch 21, Loss: 5.7178
# Epoch 9, Batch 31, Loss: 6.1643
# Epoch 9, Batch 41, Loss: 6.0619
# Epoch 9, Batch 51, Loss: 5.4432
# Epoch 9, Batch 61, Loss: 5.3985
# Epoch 9, Batch 71, Loss: 5.6020
# Epoch 9, Batch 81, Loss: 5.6121
# Epoch 10, Batch 1, Loss: 8.8516
# Epoch 10, Batch 11, Loss: 6.5078
# Epoch 10, Batch 21, Loss: 5.6617
# Epoch 10, Batch 31, Loss: 6.1091
# Epoch 10, Batch 41, Loss: 6.0098
# Epoch 10, Batch 51, Loss: 5.3946
# Epoch 10, Batch 61, Loss: 5.3525
# Epoch 10, Batch 71, Loss: 5.5558
# Epoch 10, Batch 81, Loss: 5.5680
# ------------------------embeddings_50_15_5--------------------
# 2290
# Epoch 1, Batch 1, Loss: 11.0904
# Epoch 1, Batch 11, Loss: 11.0900
# Epoch 1, Batch 21, Loss: 11.0879
# Epoch 1, Batch 31, Loss: 11.0835
# Epoch 1, Batch 41, Loss: 11.0786
# Epoch 1, Batch 51, Loss: 11.0772
# Epoch 1, Batch 61, Loss: 11.0688
# Epoch 1, Batch 71, Loss: 11.0442
# Epoch 1, Batch 81, Loss: 10.9968
# Epoch 1, Batch 91, Loss: 10.9529
# Epoch 1, Batch 101, Loss: 10.8940
# Epoch 1, Batch 111, Loss: 10.8712
# Epoch 1, Batch 121, Loss: 10.8594
# Epoch 1, Batch 131, Loss: 10.8257
# Epoch 1, Batch 141, Loss: 10.7393
# Epoch 2, Batch 1, Loss: 10.9690
# Epoch 2, Batch 11, Loss: 10.6341
# Epoch 2, Batch 21, Loss: 9.8086
# Epoch 2, Batch 31, Loss: 9.5074
# Epoch 2, Batch 41, Loss: 9.4969
# Epoch 2, Batch 51, Loss: 9.6630
# Epoch 2, Batch 61, Loss: 9.6278
# Epoch 2, Batch 71, Loss: 9.3595
# Epoch 2, Batch 81, Loss: 9.0145
# Epoch 2, Batch 91, Loss: 8.8412
# Epoch 2, Batch 101, Loss: 8.6769
# Epoch 2, Batch 111, Loss: 8.6996
# Epoch 2, Batch 121, Loss: 8.7584
# Epoch 2, Batch 131, Loss: 8.7465
# Epoch 2, Batch 141, Loss: 8.5943
# Epoch 3, Batch 1, Loss: 10.5189
# Epoch 3, Batch 11, Loss: 9.5736
# Epoch 3, Batch 21, Loss: 7.8060
# Epoch 3, Batch 31, Loss: 7.3549
# Epoch 3, Batch 41, Loss: 7.4614
# Epoch 3, Batch 51, Loss: 7.8375
# Epoch 3, Batch 61, Loss: 7.8915
# Epoch 3, Batch 71, Loss: 7.5413
# Epoch 3, Batch 81, Loss: 7.1171
# Epoch 3, Batch 91, Loss: 6.9628
# Epoch 3, Batch 101, Loss: 6.8267
# Epoch 3, Batch 111, Loss: 6.9099
# Epoch 3, Batch 121, Loss: 7.0226
# Epoch 3, Batch 131, Loss: 7.0595
# Epoch 3, Batch 141, Loss: 6.9309
# Epoch 4, Batch 1, Loss: 9.7961
# Epoch 4, Batch 11, Loss: 8.6515
# Epoch 4, Batch 21, Loss: 6.7060
# Epoch 4, Batch 31, Loss: 6.2866
# Epoch 4, Batch 41, Loss: 6.4303
# Epoch 4, Batch 51, Loss: 6.8552
# Epoch 4, Batch 61, Loss: 6.9633
# Epoch 4, Batch 71, Loss: 6.5952
# Epoch 4, Batch 81, Loss: 6.1628
# Epoch 4, Batch 91, Loss: 6.0258
# Epoch 4, Batch 101, Loss: 5.9026
# Epoch 4, Batch 111, Loss: 5.9881
# Epoch 4, Batch 121, Loss: 6.0981
# Epoch 4, Batch 131, Loss: 6.1482
# Epoch 4, Batch 141, Loss: 6.0299
# Epoch 5, Batch 1, Loss: 8.9663
# Epoch 5, Batch 11, Loss: 7.8757
# Epoch 5, Batch 21, Loss: 5.9767
# Epoch 5, Batch 31, Loss: 5.6251
# Epoch 5, Batch 41, Loss: 5.7722
# Epoch 5, Batch 51, Loss: 6.1963
# Epoch 5, Batch 61, Loss: 6.3366
# Epoch 5, Batch 71, Loss: 5.9708
# Epoch 5, Batch 81, Loss: 5.5540
# Epoch 5, Batch 91, Loss: 5.4312
# Epoch 5, Batch 101, Loss: 5.3157
# Epoch 5, Batch 111, Loss: 5.3896
# Epoch 5, Batch 121, Loss: 5.4854
# Epoch 5, Batch 131, Loss: 5.5392
# Epoch 5, Batch 141, Loss: 5.4283
# Epoch 6, Batch 1, Loss: 8.1888
# Epoch 6, Batch 11, Loss: 7.2496
# Epoch 6, Batch 21, Loss: 5.4534
# Epoch 6, Batch 31, Loss: 5.1654
# Epoch 6, Batch 41, Loss: 5.3052
# Epoch 6, Batch 51, Loss: 5.7145
# Epoch 6, Batch 61, Loss: 5.8740
# Epoch 6, Batch 71, Loss: 5.5179
# Epoch 6, Batch 81, Loss: 5.1228
# Epoch 6, Batch 91, Loss: 5.0116
# Epoch 6, Batch 101, Loss: 4.9025
# Epoch 6, Batch 111, Loss: 4.9649
# Epoch 6, Batch 121, Loss: 5.0479
# Epoch 6, Batch 131, Loss: 5.1033
# Epoch 6, Batch 141, Loss: 4.9990
# Epoch 7, Batch 1, Loss: 7.5691
# Epoch 7, Batch 11, Loss: 6.7817
# Epoch 7, Batch 21, Loss: 5.0853
# Epoch 7, Batch 31, Loss: 4.8449
# Epoch 7, Batch 41, Loss: 4.9765
# Epoch 7, Batch 51, Loss: 5.3701
# Epoch 7, Batch 61, Loss: 5.5408
# Epoch 7, Batch 71, Loss: 5.1954
# Epoch 7, Batch 81, Loss: 4.8200
# Epoch 7, Batch 91, Loss: 4.7176
# Epoch 7, Batch 101, Loss: 4.6141
# Epoch 7, Batch 111, Loss: 4.6688
# Epoch 7, Batch 121, Loss: 4.7435
# Epoch 7, Batch 131, Loss: 4.7998
# Epoch 7, Batch 141, Loss: 4.7014
# Epoch 8, Batch 1, Loss: 7.1422
# Epoch 8, Batch 11, Loss: 6.4678
# Epoch 8, Batch 21, Loss: 4.8458
# Epoch 8, Batch 31, Loss: 4.6358
# Epoch 8, Batch 41, Loss: 4.7616
# Epoch 8, Batch 51, Loss: 5.1439
# Epoch 8, Batch 61, Loss: 5.3206
# Epoch 8, Batch 71, Loss: 4.9840
# Epoch 8, Batch 81, Loss: 4.6230
# Epoch 8, Batch 91, Loss: 4.5267
# Epoch 8, Batch 101, Loss: 4.4276
# Epoch 8, Batch 111, Loss: 4.4781
# Epoch 8, Batch 121, Loss: 4.5484
# Epoch 8, Batch 131, Loss: 4.6058
# Epoch 8, Batch 141, Loss: 4.5119
# Epoch 9, Batch 1, Loss: 6.8920
# Epoch 9, Batch 11, Loss: 6.2864
# Epoch 9, Batch 21, Loss: 4.7095
# Epoch 9, Batch 31, Loss: 4.5160
# Epoch 9, Batch 41, Loss: 4.6389
# Epoch 9, Batch 51, Loss: 5.0149
# Epoch 9, Batch 61, Loss: 5.1947
# Epoch 9, Batch 71, Loss: 4.8639
# Epoch 9, Batch 81, Loss: 4.5114
# Epoch 9, Batch 91, Loss: 4.4188
# Epoch 9, Batch 101, Loss: 4.3227
# Epoch 9, Batch 111, Loss: 4.3717
# Epoch 9, Batch 121, Loss: 4.4402
# Epoch 9, Batch 131, Loss: 4.4985
# Epoch 9, Batch 141, Loss: 4.4075
# Epoch 10, Batch 1, Loss: 6.7780
# Epoch 10, Batch 11, Loss: 6.2050
# Epoch 10, Batch 21, Loss: 4.6487
# Epoch 10, Batch 31, Loss: 4.4623
# Epoch 10, Batch 41, Loss: 4.5843
# Epoch 10, Batch 51, Loss: 4.9579
# Epoch 10, Batch 61, Loss: 5.1391
# Epoch 10, Batch 71, Loss: 4.8111
# Epoch 10, Batch 81, Loss: 4.4626
# Epoch 10, Batch 91, Loss: 4.3718
# Epoch 10, Batch 101, Loss: 4.2774
# Epoch 10, Batch 111, Loss: 4.3262
# Epoch 10, Batch 121, Loss: 4.3943
# Epoch 10, Batch 131, Loss: 4.4532
# Epoch 10, Batch 141, Loss: 4.3638
# ------------------------embeddings_100_5_1--------------------
# 462
# Epoch 1, Batch 1, Loss: 4.1589
# Epoch 1, Batch 11, Loss: 4.1584
# Epoch 1, Batch 21, Loss: 4.1551
# Epoch 2, Batch 1, Loss: 4.1487
# Epoch 2, Batch 11, Loss: 4.1304
# Epoch 2, Batch 21, Loss: 4.0994
# Epoch 3, Batch 1, Loss: 4.1070
# Epoch 3, Batch 11, Loss: 4.0275
# Epoch 3, Batch 21, Loss: 3.9432
# Epoch 4, Batch 1, Loss: 4.0168
# Epoch 4, Batch 11, Loss: 3.8562
# Epoch 4, Batch 21, Loss: 3.7175
# Epoch 5, Batch 1, Loss: 3.8928
# Epoch 5, Batch 11, Loss: 3.6703
# Epoch 5, Batch 21, Loss: 3.4936
# Epoch 6, Batch 1, Loss: 3.7645
# Epoch 6, Batch 11, Loss: 3.5118
# Epoch 6, Batch 21, Loss: 3.3136
# Epoch 7, Batch 1, Loss: 3.6557
# Epoch 7, Batch 11, Loss: 3.3939
# Epoch 7, Batch 21, Loss: 3.1850
# Epoch 8, Batch 1, Loss: 3.5770
# Epoch 8, Batch 11, Loss: 3.3152
# Epoch 8, Batch 21, Loss: 3.1019
# Epoch 9, Batch 1, Loss: 3.5293
# Epoch 9, Batch 11, Loss: 3.2697
# Epoch 9, Batch 21, Loss: 3.0555
# Epoch 10, Batch 1, Loss: 3.5072
# Epoch 10, Batch 11, Loss: 3.2493
# Epoch 10, Batch 21, Loss: 3.0357
# ------------------------embeddings_100_5_3--------------------
# 1380
# Epoch 1, Batch 1, Loss: 4.1589
# Epoch 1, Batch 11, Loss: 4.1587
# Epoch 1, Batch 21, Loss: 4.1574
# Epoch 1, Batch 31, Loss: 4.1566
# Epoch 1, Batch 41, Loss: 4.1526
# Epoch 1, Batch 51, Loss: 4.1375
# Epoch 1, Batch 61, Loss: 4.1250
# Epoch 1, Batch 71, Loss: 4.1244
# Epoch 1, Batch 81, Loss: 4.1106
# Epoch 2, Batch 1, Loss: 4.1451
# Epoch 2, Batch 11, Loss: 3.9929
# Epoch 2, Batch 21, Loss: 3.8711
# Epoch 2, Batch 31, Loss: 3.9001
# Epoch 2, Batch 41, Loss: 3.8546
# Epoch 2, Batch 51, Loss: 3.7161
# Epoch 2, Batch 61, Loss: 3.6658
# Epoch 2, Batch 71, Loss: 3.6946
# Epoch 2, Batch 81, Loss: 3.6658
# Epoch 3, Batch 1, Loss: 4.0775
# Epoch 3, Batch 11, Loss: 3.5519
# Epoch 3, Batch 21, Loss: 3.2706
# Epoch 3, Batch 31, Loss: 3.3857
# Epoch 3, Batch 41, Loss: 3.3343
# Epoch 3, Batch 51, Loss: 3.1283
# Epoch 3, Batch 61, Loss: 3.0845
# Epoch 3, Batch 71, Loss: 3.1539
# Epoch 3, Batch 81, Loss: 3.1396
# Epoch 4, Batch 1, Loss: 3.9406
# Epoch 4, Batch 11, Loss: 3.2003
# Epoch 4, Batch 21, Loss: 2.8778
# Epoch 4, Batch 31, Loss: 3.0382
# Epoch 4, Batch 41, Loss: 2.9881
# Epoch 4, Batch 51, Loss: 2.7611
# Epoch 4, Batch 61, Loss: 2.7228
# Epoch 4, Batch 71, Loss: 2.8064
# Epoch 4, Batch 81, Loss: 2.7990
# Epoch 5, Batch 1, Loss: 3.7616
# Epoch 5, Batch 11, Loss: 2.9372
# Epoch 5, Batch 21, Loss: 2.6149
# Epoch 5, Batch 31, Loss: 2.7968
# Epoch 5, Batch 41, Loss: 2.7481
# Epoch 5, Batch 51, Loss: 2.5156
# Epoch 5, Batch 61, Loss: 2.4810
# Epoch 5, Batch 71, Loss: 2.5677
# Epoch 5, Batch 81, Loss: 2.5639
# Epoch 6, Batch 1, Loss: 3.5743
# Epoch 6, Batch 11, Loss: 2.7407
# Epoch 6, Batch 21, Loss: 2.4293
# Epoch 6, Batch 31, Loss: 2.6215
# Epoch 6, Batch 41, Loss: 2.5748
# Epoch 6, Batch 51, Loss: 2.3434
# Epoch 6, Batch 61, Loss: 2.3120
# Epoch 6, Batch 71, Loss: 2.3979
# Epoch 6, Batch 81, Loss: 2.3967
# Epoch 7, Batch 1, Loss: 3.4089
# Epoch 7, Batch 11, Loss: 2.5996
# Epoch 7, Batch 21, Loss: 2.3000
# Epoch 7, Batch 31, Loss: 2.4970
# Epoch 7, Batch 41, Loss: 2.4525
# Epoch 7, Batch 51, Loss: 2.2246
# Epoch 7, Batch 61, Loss: 2.1957
# Epoch 7, Batch 71, Loss: 2.2802
# Epoch 7, Batch 81, Loss: 2.2810
# Epoch 8, Batch 1, Loss: 3.2847
# Epoch 8, Batch 11, Loss: 2.5057
# Epoch 8, Batch 21, Loss: 2.2156
# Epoch 8, Batch 31, Loss: 2.4149
# Epoch 8, Batch 41, Loss: 2.3723
# Epoch 8, Batch 51, Loss: 2.1478
# Epoch 8, Batch 61, Loss: 2.1209
# Epoch 8, Batch 71, Loss: 2.2044
# Epoch 8, Batch 81, Loss: 2.2067
# Epoch 9, Batch 1, Loss: 3.2072
# Epoch 9, Batch 11, Loss: 2.4510
# Epoch 9, Batch 21, Loss: 2.1669
# Epoch 9, Batch 31, Loss: 2.3675
# Epoch 9, Batch 41, Loss: 2.3262
# Epoch 9, Batch 51, Loss: 2.1042
# Epoch 9, Batch 61, Loss: 2.0787
# Epoch 9, Batch 71, Loss: 2.1618
# Epoch 9, Batch 81, Loss: 2.1652
# Epoch 10, Batch 1, Loss: 3.1704
# Epoch 10, Batch 11, Loss: 2.4260
# Epoch 10, Batch 21, Loss: 2.1449
# Epoch 10, Batch 31, Loss: 2.3462
# Epoch 10, Batch 41, Loss: 2.3057
# Epoch 10, Batch 51, Loss: 2.0850
# Epoch 10, Batch 61, Loss: 2.0603
# Epoch 10, Batch 71, Loss: 2.1434
# Epoch 10, Batch 81, Loss: 2.1475
# ------------------------embeddings_100_5_5--------------------
# 2290
# Epoch 1, Batch 1, Loss: 4.1589
# Epoch 1, Batch 11, Loss: 4.1588
# Epoch 1, Batch 21, Loss: 4.1579
# Epoch 1, Batch 31, Loss: 4.1557
# Epoch 1, Batch 41, Loss: 4.1534
# Epoch 1, Batch 51, Loss: 4.1528
# Epoch 1, Batch 61, Loss: 4.1488
# Epoch 1, Batch 71, Loss: 4.1346
# Epoch 1, Batch 81, Loss: 4.1066
# Epoch 1, Batch 91, Loss: 4.0832
# Epoch 1, Batch 101, Loss: 4.0485
# Epoch 1, Batch 111, Loss: 4.0397
# Epoch 1, Batch 121, Loss: 4.0358
# Epoch 1, Batch 131, Loss: 4.0239
# Epoch 1, Batch 141, Loss: 3.9846
# Epoch 2, Batch 1, Loss: 4.1078
# Epoch 2, Batch 11, Loss: 3.9746
# Epoch 2, Batch 21, Loss: 3.6160
# Epoch 2, Batch 31, Loss: 3.4907
# Epoch 2, Batch 41, Loss: 3.4978
# Epoch 2, Batch 51, Loss: 3.5705
# Epoch 2, Batch 61, Loss: 3.5674
# Epoch 2, Batch 71, Loss: 3.4648
# Epoch 2, Batch 81, Loss: 3.3275
# Epoch 2, Batch 91, Loss: 3.2698
# Epoch 2, Batch 101, Loss: 3.2060
# Epoch 2, Batch 111, Loss: 3.2234
# Epoch 2, Batch 121, Loss: 3.2529
# Epoch 2, Batch 131, Loss: 3.2568
# Epoch 2, Batch 141, Loss: 3.2078
# Epoch 3, Batch 1, Loss: 3.8897
# Epoch 3, Batch 11, Loss: 3.5844
# Epoch 3, Batch 21, Loss: 2.9682
# Epoch 3, Batch 31, Loss: 2.8144
# Epoch 3, Batch 41, Loss: 2.8549
# Epoch 3, Batch 51, Loss: 2.9905
# Epoch 3, Batch 61, Loss: 3.0178
# Epoch 3, Batch 71, Loss: 2.8961
# Epoch 3, Batch 81, Loss: 2.7402
# Epoch 3, Batch 91, Loss: 2.6909
# Epoch 3, Batch 101, Loss: 2.6365
# Epoch 3, Batch 111, Loss: 2.6707
# Epoch 3, Batch 121, Loss: 2.7150
# Epoch 3, Batch 131, Loss: 2.7295
# Epoch 3, Batch 141, Loss: 2.6856
# Epoch 4, Batch 1, Loss: 3.5400
# Epoch 4, Batch 11, Loss: 3.2373
# Epoch 4, Batch 21, Loss: 2.5745
# Epoch 4, Batch 31, Loss: 2.4330
# Epoch 4, Batch 41, Loss: 2.4836
# Epoch 4, Batch 51, Loss: 2.6364
# Epoch 4, Batch 61, Loss: 2.6803
# Epoch 4, Batch 71, Loss: 2.5518
# Epoch 4, Batch 81, Loss: 2.3972
# Epoch 4, Batch 91, Loss: 2.3543
# Epoch 4, Batch 101, Loss: 2.3042
# Epoch 4, Batch 111, Loss: 2.3393
# Epoch 4, Batch 121, Loss: 2.3829
# Epoch 4, Batch 131, Loss: 2.3997
# Epoch 4, Batch 141, Loss: 2.3583
# Epoch 5, Batch 1, Loss: 3.1505
# Epoch 5, Batch 11, Loss: 2.9450
# Epoch 5, Batch 21, Loss: 2.2966
# Epoch 5, Batch 31, Loss: 2.1765
# Epoch 5, Batch 41, Loss: 2.2286
# Epoch 5, Batch 51, Loss: 2.3812
# Epoch 5, Batch 61, Loss: 2.4341
# Epoch 5, Batch 71, Loss: 2.3040
# Epoch 5, Batch 81, Loss: 2.1578
# Epoch 5, Batch 91, Loss: 2.1200
# Epoch 5, Batch 101, Loss: 2.0726
# Epoch 5, Batch 111, Loss: 2.1051
# Epoch 5, Batch 121, Loss: 2.1449
# Epoch 5, Batch 131, Loss: 2.1622
# Epoch 5, Batch 141, Loss: 2.1233
# Epoch 6, Batch 1, Loss: 2.8077
# Epoch 6, Batch 11, Loss: 2.7096
# Epoch 6, Batch 21, Loss: 2.0944
# Epoch 6, Batch 31, Loss: 1.9944
# Epoch 6, Batch 41, Loss: 2.0458
# Epoch 6, Batch 51, Loss: 2.1927
# Epoch 6, Batch 61, Loss: 2.2506
# Epoch 6, Batch 71, Loss: 2.1221
# Epoch 6, Batch 81, Loss: 1.9853
# Epoch 6, Batch 91, Loss: 1.9513
# Epoch 6, Batch 101, Loss: 1.9064
# Epoch 6, Batch 111, Loss: 1.9365
# Epoch 6, Batch 121, Loss: 1.9732
# Epoch 6, Batch 131, Loss: 1.9906
# Epoch 6, Batch 141, Loss: 1.9543
# Epoch 7, Batch 1, Loss: 2.5540
# Epoch 7, Batch 11, Loss: 2.5365
# Epoch 7, Batch 21, Loss: 1.9541
# Epoch 7, Batch 31, Loss: 1.8687
# Epoch 7, Batch 41, Loss: 1.9195
# Epoch 7, Batch 51, Loss: 2.0605
# Epoch 7, Batch 61, Loss: 2.1208
# Epoch 7, Batch 71, Loss: 1.9950
# Epoch 7, Batch 81, Loss: 1.8661
# Epoch 7, Batch 91, Loss: 1.8348
# Epoch 7, Batch 101, Loss: 1.7921
# Epoch 7, Batch 111, Loss: 1.8208
# Epoch 7, Batch 121, Loss: 1.8556
# Epoch 7, Batch 131, Loss: 1.8730
# Epoch 7, Batch 141, Loss: 1.8390
# Epoch 8, Batch 1, Loss: 2.3897
# Epoch 8, Batch 11, Loss: 2.4225
# Epoch 8, Batch 21, Loss: 1.8644
# Epoch 8, Batch 31, Loss: 1.7882
# Epoch 8, Batch 41, Loss: 1.8385
# Epoch 8, Batch 51, Loss: 1.9753
# Epoch 8, Batch 61, Loss: 2.0369
# Epoch 8, Batch 71, Loss: 1.9136
# Epoch 8, Batch 81, Loss: 1.7900
# Epoch 8, Batch 91, Loss: 1.7605
# Epoch 8, Batch 101, Loss: 1.7195
# Epoch 8, Batch 111, Loss: 1.7476
# Epoch 8, Batch 121, Loss: 1.7814
# Epoch 8, Batch 131, Loss: 1.7990
# Epoch 8, Batch 141, Loss: 1.7666
# Epoch 9, Batch 1, Loss: 2.2973
# Epoch 9, Batch 11, Loss: 2.3575
# Epoch 9, Batch 21, Loss: 1.8142
# Epoch 9, Batch 31, Loss: 1.7426
# Epoch 9, Batch 41, Loss: 1.7930
# Epoch 9, Batch 51, Loss: 1.9275
# Epoch 9, Batch 61, Loss: 1.9896
# Epoch 9, Batch 71, Loss: 1.8679
# Epoch 9, Batch 81, Loss: 1.7475
# Epoch 9, Batch 91, Loss: 1.7190
# Epoch 9, Batch 101, Loss: 1.6792
# Epoch 9, Batch 111, Loss: 1.7071
# Epoch 9, Batch 121, Loss: 1.7406
# Epoch 9, Batch 131, Loss: 1.7583
# Epoch 9, Batch 141, Loss: 1.7270
# Epoch 10, Batch 1, Loss: 2.2563
# Epoch 10, Batch 11, Loss: 2.3287
# Epoch 10, Batch 21, Loss: 1.7919
# Epoch 10, Batch 31, Loss: 1.7224
# Epoch 10, Batch 41, Loss: 1.7728
# Epoch 10, Batch 51, Loss: 1.9065
# Epoch 10, Batch 61, Loss: 1.9688
# Epoch 10, Batch 71, Loss: 1.8480
# Epoch 10, Batch 81, Loss: 1.7289
# Epoch 10, Batch 91, Loss: 1.7010
# Epoch 10, Batch 101, Loss: 1.6618
# Epoch 10, Batch 111, Loss: 1.6897
# Epoch 10, Batch 121, Loss: 1.7232
# Epoch 10, Batch 131, Loss: 1.7410
# Epoch 10, Batch 141, Loss: 1.7103
# ------------------------embeddings_100_10_1--------------------
# 462
# Epoch 1, Batch 1, Loss: 7.6246
# Epoch 1, Batch 11, Loss: 7.6234
# Epoch 1, Batch 21, Loss: 7.6159
# Epoch 2, Batch 1, Loss: 7.6027
# Epoch 2, Batch 11, Loss: 7.5534
# Epoch 2, Batch 21, Loss: 7.4902
# Epoch 3, Batch 1, Loss: 7.5070
# Epoch 3, Batch 11, Loss: 7.3048
# Epoch 3, Batch 21, Loss: 7.1427
# Epoch 4, Batch 1, Loss: 7.3066
# Epoch 4, Batch 11, Loss: 6.9040
# Epoch 4, Batch 21, Loss: 6.6493
# Epoch 5, Batch 1, Loss: 7.0413
# Epoch 5, Batch 11, Loss: 6.4846
# Epoch 5, Batch 21, Loss: 6.1701
# Epoch 6, Batch 1, Loss: 6.7744
# Epoch 6, Batch 11, Loss: 6.1394
# Epoch 6, Batch 21, Loss: 5.7930
# Epoch 7, Batch 1, Loss: 6.5503
# Epoch 7, Batch 11, Loss: 5.8898
# Epoch 7, Batch 21, Loss: 5.5285
# Epoch 8, Batch 1, Loss: 6.3885
# Epoch 8, Batch 11, Loss: 5.7266
# Epoch 8, Batch 21, Loss: 5.3602
# Epoch 9, Batch 1, Loss: 6.2900
# Epoch 9, Batch 11, Loss: 5.6336
# Epoch 9, Batch 21, Loss: 5.2673
# Epoch 10, Batch 1, Loss: 6.2440
# Epoch 10, Batch 11, Loss: 5.5923
# Epoch 10, Batch 21, Loss: 5.2280
# ------------------------embeddings_100_10_3--------------------
# 1380
# Epoch 1, Batch 1, Loss: 7.6246
# Epoch 1, Batch 11, Loss: 7.6243
# Epoch 1, Batch 21, Loss: 7.6217
# Epoch 1, Batch 31, Loss: 7.6196
# Epoch 1, Batch 41, Loss: 7.6102
# Epoch 1, Batch 51, Loss: 7.5812
# Epoch 1, Batch 61, Loss: 7.5545
# Epoch 1, Batch 71, Loss: 7.5499
# Epoch 1, Batch 81, Loss: 7.5143
# Epoch 2, Batch 1, Loss: 7.5972
# Epoch 2, Batch 11, Loss: 7.2582
# Epoch 2, Batch 21, Loss: 6.9972
# Epoch 2, Batch 31, Loss: 7.0333
# Epoch 2, Batch 41, Loss: 6.9210
# Epoch 2, Batch 51, Loss: 6.6514
# Epoch 2, Batch 61, Loss: 6.5454
# Epoch 2, Batch 71, Loss: 6.5941
# Epoch 2, Batch 81, Loss: 6.5117
# Epoch 3, Batch 1, Loss: 7.4515
# Epoch 3, Batch 11, Loss: 6.3384
# Epoch 3, Batch 21, Loss: 5.7477
# Epoch 3, Batch 31, Loss: 5.9298
# Epoch 3, Batch 41, Loss: 5.8071
# Epoch 3, Batch 51, Loss: 5.4119
# Epoch 3, Batch 61, Loss: 5.3259
# Epoch 3, Batch 71, Loss: 5.4511
# Epoch 3, Batch 81, Loss: 5.3990
# Epoch 4, Batch 1, Loss: 7.1601
# Epoch 4, Batch 11, Loss: 5.6550
# Epoch 4, Batch 21, Loss: 4.9799
# Epoch 4, Batch 31, Loss: 5.2352
# Epoch 4, Batch 41, Loss: 5.1255
# Epoch 4, Batch 51, Loss: 4.6917
# Epoch 4, Batch 61, Loss: 4.6192
# Epoch 4, Batch 71, Loss: 4.7617
# Epoch 4, Batch 81, Loss: 4.7271
# Epoch 5, Batch 1, Loss: 6.7794
# Epoch 5, Batch 11, Loss: 5.1482
# Epoch 5, Batch 21, Loss: 4.4822
# Epoch 5, Batch 31, Loss: 4.7665
# Epoch 5, Batch 41, Loss: 4.6695
# Epoch 5, Batch 51, Loss: 4.2304
# Epoch 5, Batch 61, Loss: 4.1658
# Epoch 5, Batch 71, Loss: 4.3045
# Epoch 5, Batch 81, Loss: 4.2802
# Epoch 6, Batch 1, Loss: 6.3812
# Epoch 6, Batch 11, Loss: 4.7660
# Epoch 6, Batch 21, Loss: 4.1343
# Epoch 6, Batch 31, Loss: 4.4276
# Epoch 6, Batch 41, Loss: 4.3420
# Epoch 6, Batch 51, Loss: 3.9117
# Epoch 6, Batch 61, Loss: 3.8531
# Epoch 6, Batch 71, Loss: 3.9835
# Epoch 6, Batch 81, Loss: 3.9664
# Epoch 7, Batch 1, Loss: 6.0313
# Epoch 7, Batch 11, Loss: 4.4883
# Epoch 7, Batch 21, Loss: 3.8921
# Epoch 7, Batch 31, Loss: 4.1863
# Epoch 7, Batch 41, Loss: 4.1101
# Epoch 7, Batch 51, Loss: 3.6920
# Epoch 7, Batch 61, Loss: 3.6385
# Epoch 7, Batch 71, Loss: 3.7618
# Epoch 7, Batch 81, Loss: 3.7498
# Epoch 8, Batch 1, Loss: 5.7704
# Epoch 8, Batch 11, Loss: 4.3023
# Epoch 8, Batch 21, Loss: 3.7336
# Epoch 8, Batch 31, Loss: 4.0265
# Epoch 8, Batch 41, Loss: 3.9572
# Epoch 8, Batch 51, Loss: 3.5499
# Epoch 8, Batch 61, Loss: 3.5002
# Epoch 8, Batch 71, Loss: 3.6192
# Epoch 8, Batch 81, Loss: 3.6108
# Epoch 9, Batch 1, Loss: 5.6086
# Epoch 9, Batch 11, Loss: 4.1939
# Epoch 9, Batch 21, Loss: 3.6421
# Epoch 9, Batch 31, Loss: 3.9343
# Epoch 9, Batch 41, Loss: 3.8693
# Epoch 9, Batch 51, Loss: 3.4691
# Epoch 9, Batch 61, Loss: 3.4222
# Epoch 9, Batch 71, Loss: 3.5392
# Epoch 9, Batch 81, Loss: 3.5331
# Epoch 10, Batch 1, Loss: 5.5322
# Epoch 10, Batch 11, Loss: 4.1444
# Epoch 10, Batch 21, Loss: 3.6007
# Epoch 10, Batch 31, Loss: 3.8928
# Epoch 10, Batch 41, Loss: 3.8301
# Epoch 10, Batch 51, Loss: 3.4334
# Epoch 10, Batch 61, Loss: 3.3881
# Epoch 10, Batch 71, Loss: 3.5048
# Epoch 10, Batch 81, Loss: 3.5000
# ------------------------embeddings_100_10_5--------------------
# 2290
# Epoch 1, Batch 1, Loss: 7.6246
# Epoch 1, Batch 11, Loss: 7.6244
# Epoch 1, Batch 21, Loss: 7.6226
# Epoch 1, Batch 31, Loss: 7.6181
# Epoch 1, Batch 41, Loss: 7.6129
# Epoch 1, Batch 51, Loss: 7.6109
# Epoch 1, Batch 61, Loss: 7.6009
# Epoch 1, Batch 71, Loss: 7.5685
# Epoch 1, Batch 81, Loss: 7.5098
# Epoch 1, Batch 91, Loss: 7.4578
# Epoch 1, Batch 101, Loss: 7.3876
# Epoch 1, Batch 111, Loss: 7.3641
# Epoch 1, Batch 121, Loss: 7.3524
# Epoch 1, Batch 131, Loss: 7.3204
# Epoch 1, Batch 141, Loss: 7.2356
# Epoch 2, Batch 1, Loss: 7.5239
# Epoch 2, Batch 11, Loss: 7.1636
# Epoch 2, Batch 21, Loss: 6.3501
# Epoch 2, Batch 31, Loss: 6.1097
# Epoch 2, Batch 41, Loss: 6.1259
# Epoch 2, Batch 51, Loss: 6.2833
# Epoch 2, Batch 61, Loss: 6.2663
# Epoch 2, Batch 71, Loss: 6.0371
# Epoch 2, Batch 81, Loss: 5.7615
# Epoch 2, Batch 91, Loss: 5.6422
# Epoch 2, Batch 101, Loss: 5.5269
# Epoch 2, Batch 111, Loss: 5.5607
# Epoch 2, Batch 121, Loss: 5.6141
# Epoch 2, Batch 131, Loss: 5.6176
# Epoch 2, Batch 141, Loss: 5.5200
# Epoch 3, Batch 1, Loss: 7.0737
# Epoch 3, Batch 11, Loss: 6.3344
# Epoch 3, Batch 21, Loss: 5.0471
# Epoch 3, Batch 31, Loss: 4.7644
# Epoch 3, Batch 41, Loss: 4.8566
# Epoch 3, Batch 51, Loss: 5.1271
# Epoch 3, Batch 61, Loss: 5.1796
# Epoch 3, Batch 71, Loss: 4.9175
# Epoch 3, Batch 81, Loss: 4.6138
# Epoch 3, Batch 91, Loss: 4.5127
# Epoch 3, Batch 101, Loss: 4.4213
# Epoch 3, Batch 111, Loss: 4.4811
# Epoch 3, Batch 121, Loss: 4.5494
# Epoch 3, Batch 131, Loss: 4.5766
# Epoch 3, Batch 141, Loss: 4.4935
# Epoch 4, Batch 1, Loss: 6.3559
# Epoch 4, Batch 11, Loss: 5.6106
# Epoch 4, Batch 21, Loss: 4.2993
# Epoch 4, Batch 31, Loss: 4.0633
# Epoch 4, Batch 41, Loss: 4.1731
# Epoch 4, Batch 51, Loss: 4.4584
# Epoch 4, Batch 61, Loss: 4.5494
# Epoch 4, Batch 71, Loss: 4.2853
# Epoch 4, Batch 81, Loss: 3.9924
# Epoch 4, Batch 91, Loss: 3.9041
# Epoch 4, Batch 101, Loss: 3.8237
# Epoch 4, Batch 111, Loss: 3.8769
# Epoch 4, Batch 121, Loss: 3.9320
# Epoch 4, Batch 131, Loss: 3.9640
# Epoch 4, Batch 141, Loss: 3.8867
# Epoch 5, Batch 1, Loss: 5.5615
# Epoch 5, Batch 11, Loss: 4.9871
# Epoch 5, Batch 21, Loss: 3.7632
# Epoch 5, Batch 31, Loss: 3.5857
# Epoch 5, Batch 41, Loss: 3.6911
# Epoch 5, Batch 51, Loss: 3.9638
# Epoch 5, Batch 61, Loss: 4.0775
# Epoch 5, Batch 71, Loss: 3.8226
# Epoch 5, Batch 81, Loss: 3.5531
# Epoch 5, Batch 91, Loss: 3.4759
# Epoch 5, Batch 101, Loss: 3.4036
# Epoch 5, Batch 111, Loss: 3.4467
# Epoch 5, Batch 121, Loss: 3.4883
# Epoch 5, Batch 131, Loss: 3.5215
# Epoch 5, Batch 141, Loss: 3.4502
# Epoch 6, Batch 1, Loss: 4.8706
# Epoch 6, Batch 11, Loss: 4.4847
# Epoch 6, Batch 21, Loss: 3.3704
# Epoch 6, Batch 31, Loss: 3.2410
# Epoch 6, Batch 41, Loss: 3.3369
# Epoch 6, Batch 51, Loss: 3.5911
# Epoch 6, Batch 61, Loss: 3.7178
# Epoch 6, Batch 71, Loss: 3.4755
# Epoch 6, Batch 81, Loss: 3.2295
# Epoch 6, Batch 91, Loss: 3.1611
# Epoch 6, Batch 101, Loss: 3.0959
# Epoch 6, Batch 111, Loss: 3.1321
# Epoch 6, Batch 121, Loss: 3.1651
# Epoch 6, Batch 131, Loss: 3.1989
# Epoch 6, Batch 141, Loss: 3.1337
# Epoch 7, Batch 1, Loss: 4.3661
# Epoch 7, Batch 11, Loss: 4.1215
# Epoch 7, Batch 21, Loss: 3.0995
# Epoch 7, Batch 31, Loss: 3.0017
# Epoch 7, Batch 41, Loss: 3.0897
# Epoch 7, Batch 51, Loss: 3.3285
# Epoch 7, Batch 61, Loss: 3.4619
# Epoch 7, Batch 71, Loss: 3.2310
# Epoch 7, Batch 81, Loss: 3.0034
# Epoch 7, Batch 91, Loss: 2.9413
# Epoch 7, Batch 101, Loss: 2.8818
# Epoch 7, Batch 111, Loss: 2.9144
# Epoch 7, Batch 121, Loss: 2.9431
# Epoch 7, Batch 131, Loss: 2.9773
# Epoch 7, Batch 141, Loss: 2.9174
# Epoch 8, Batch 1, Loss: 4.0432
# Epoch 8, Batch 11, Loss: 3.8874
# Epoch 8, Batch 21, Loss: 2.9287
# Epoch 8, Batch 31, Loss: 2.8485
# Epoch 8, Batch 41, Loss: 2.9316
# Epoch 8, Batch 51, Loss: 3.1604
# Epoch 8, Batch 61, Loss: 3.2967
# Epoch 8, Batch 71, Loss: 3.0743
# Epoch 8, Batch 81, Loss: 2.8589
# Epoch 8, Batch 91, Loss: 2.8008
# Epoch 8, Batch 101, Loss: 2.7455
# Epoch 8, Batch 111, Loss: 2.7765
# Epoch 8, Batch 121, Loss: 2.8036
# Epoch 8, Batch 131, Loss: 2.8382
# Epoch 8, Batch 141, Loss: 2.7820
# Epoch 9, Batch 1, Loss: 3.8634
# Epoch 9, Batch 11, Loss: 3.7566
# Epoch 9, Batch 21, Loss: 2.8339
# Epoch 9, Batch 31, Loss: 2.7622
# Epoch 9, Batch 41, Loss: 2.8430
# Epoch 9, Batch 51, Loss: 3.0664
# Epoch 9, Batch 61, Loss: 3.2039
# Epoch 9, Batch 71, Loss: 2.9866
# Epoch 9, Batch 81, Loss: 2.7781
# Epoch 9, Batch 91, Loss: 2.7224
# Epoch 9, Batch 101, Loss: 2.6697
# Epoch 9, Batch 111, Loss: 2.7004
# Epoch 9, Batch 121, Loss: 2.7270
# Epoch 9, Batch 131, Loss: 2.7619
# Epoch 9, Batch 141, Loss: 2.7081
# Epoch 10, Batch 1, Loss: 3.7839
# Epoch 10, Batch 11, Loss: 3.6991
# Epoch 10, Batch 21, Loss: 2.7923
# Epoch 10, Batch 31, Loss: 2.7239
# Epoch 10, Batch 41, Loss: 2.8038
# Epoch 10, Batch 51, Loss: 3.0252
# Epoch 10, Batch 61, Loss: 3.1632
# Epoch 10, Batch 71, Loss: 2.9484
# Epoch 10, Batch 81, Loss: 2.7428
# Epoch 10, Batch 91, Loss: 2.6884
# Epoch 10, Batch 101, Loss: 2.6370
# Epoch 10, Batch 111, Loss: 2.6678
# Epoch 10, Batch 121, Loss: 2.6944
# Epoch 10, Batch 131, Loss: 2.7297
# Epoch 10, Batch 141, Loss: 2.6770
# ------------------------embeddings_100_15_1--------------------
# 462
# Epoch 1, Batch 1, Loss: 11.0904
# Epoch 1, Batch 11, Loss: 11.0880
# Epoch 1, Batch 21, Loss: 11.0746
# Epoch 2, Batch 1, Loss: 11.0499
# Epoch 2, Batch 11, Loss: 10.9740
# Epoch 2, Batch 21, Loss: 10.8635
# Epoch 3, Batch 1, Loss: 10.8816
# Epoch 3, Batch 11, Loss: 10.5772
# Epoch 3, Batch 21, Loss: 10.2952
# Epoch 4, Batch 1, Loss: 10.5382
# Epoch 4, Batch 11, Loss: 9.9456
# Epoch 4, Batch 21, Loss: 9.5036
# Epoch 5, Batch 1, Loss: 10.0889
# Epoch 5, Batch 11, Loss: 9.2905
# Epoch 5, Batch 21, Loss: 8.7485
# Epoch 6, Batch 1, Loss: 9.6421
# Epoch 6, Batch 11, Loss: 8.7553
# Epoch 6, Batch 21, Loss: 8.1640
# Epoch 7, Batch 1, Loss: 9.2723
# Epoch 7, Batch 11, Loss: 8.3705
# Epoch 7, Batch 21, Loss: 7.7594
# Epoch 8, Batch 1, Loss: 9.0089
# Epoch 8, Batch 11, Loss: 8.1198
# Epoch 8, Batch 21, Loss: 7.5042
# Epoch 9, Batch 1, Loss: 8.8503
# Epoch 9, Batch 11, Loss: 7.9772
# Epoch 9, Batch 21, Loss: 7.3640
# Epoch 10, Batch 1, Loss: 8.7767
# Epoch 10, Batch 11, Loss: 7.9139
# Epoch 10, Batch 21, Loss: 7.3047
# ------------------------embeddings_100_15_3--------------------
# 1380
# Epoch 1, Batch 1, Loss: 11.0904
# Epoch 1, Batch 11, Loss: 11.0895
# Epoch 1, Batch 21, Loss: 11.0846
# Epoch 1, Batch 31, Loss: 11.0810
# Epoch 1, Batch 41, Loss: 11.0640
# Epoch 1, Batch 51, Loss: 11.0119
# Epoch 1, Batch 61, Loss: 10.9639
# Epoch 1, Batch 71, Loss: 10.9535
# Epoch 1, Batch 81, Loss: 10.8941
# Epoch 2, Batch 1, Loss: 11.0284
# Epoch 2, Batch 11, Loss: 10.4310
# Epoch 2, Batch 21, Loss: 10.0147
# Epoch 2, Batch 31, Loss: 10.0959
# Epoch 2, Batch 41, Loss: 9.9031
# Epoch 2, Batch 51, Loss: 9.4427
# Epoch 2, Batch 61, Loss: 9.2681
# Epoch 2, Batch 71, Loss: 9.3420
# Epoch 2, Batch 81, Loss: 9.2247
# Epoch 3, Batch 1, Loss: 10.7339
# Epoch 3, Batch 11, Loss: 8.8660
# Epoch 3, Batch 21, Loss: 7.9966
# Epoch 3, Batch 31, Loss: 8.3212
# Epoch 3, Batch 41, Loss: 8.1180
# Epoch 3, Batch 51, Loss: 7.4692
# Epoch 3, Batch 61, Loss: 7.3452
# Epoch 3, Batch 71, Loss: 7.5366
# Epoch 3, Batch 81, Loss: 7.4800
# Epoch 4, Batch 1, Loss: 10.1892
# Epoch 4, Batch 11, Loss: 7.7638
# Epoch 4, Batch 21, Loss: 6.8307
# Epoch 4, Batch 31, Loss: 7.2470
# Epoch 4, Batch 41, Loss: 7.0762
# Epoch 4, Batch 51, Loss: 6.3885
# Epoch 4, Batch 61, Loss: 6.2974
# Epoch 4, Batch 71, Loss: 6.5063
# Epoch 4, Batch 81, Loss: 6.4767
# Epoch 5, Batch 1, Loss: 9.5100
# Epoch 5, Batch 11, Loss: 6.9725
# Epoch 5, Batch 21, Loss: 6.0943
# Epoch 5, Batch 31, Loss: 6.5331
# Epoch 5, Batch 41, Loss: 6.3904
# Epoch 5, Batch 51, Loss: 5.7142
# Epoch 5, Batch 61, Loss: 5.6414
# Epoch 5, Batch 71, Loss: 5.8354
# Epoch 5, Batch 81, Loss: 5.8189
# Epoch 6, Batch 1, Loss: 8.8237
# Epoch 6, Batch 11, Loss: 6.3812
# Epoch 6, Batch 21, Loss: 5.5793
# Epoch 6, Batch 31, Loss: 6.0173
# Epoch 6, Batch 41, Loss: 5.8971
# Epoch 6, Batch 51, Loss: 5.2491
# Epoch 6, Batch 61, Loss: 5.1884
# Epoch 6, Batch 71, Loss: 5.3636
# Epoch 6, Batch 81, Loss: 5.3555
# Epoch 7, Batch 1, Loss: 8.2371
# Epoch 7, Batch 11, Loss: 5.9534
# Epoch 7, Batch 21, Loss: 5.2188
# Epoch 7, Batch 31, Loss: 5.6495
# Epoch 7, Batch 41, Loss: 5.5464
# Epoch 7, Batch 51, Loss: 4.9271
# Epoch 7, Batch 61, Loss: 4.8753
# Epoch 7, Batch 71, Loss: 5.0360
# Epoch 7, Batch 81, Loss: 5.0341
# Epoch 8, Batch 1, Loss: 7.8090
# Epoch 8, Batch 11, Loss: 5.6684
# Epoch 8, Batch 21, Loss: 4.9824
# Epoch 8, Batch 31, Loss: 5.4062
# Epoch 8, Batch 41, Loss: 5.3151
# Epoch 8, Batch 51, Loss: 4.7181
# Epoch 8, Batch 61, Loss: 4.6727
# Epoch 8, Batch 71, Loss: 4.8249
# Epoch 8, Batch 81, Loss: 4.8274
# Epoch 9, Batch 1, Loss: 7.5475
# Epoch 9, Batch 11, Loss: 5.5029
# Epoch 9, Batch 21, Loss: 4.8460
# Epoch 9, Batch 31, Loss: 5.2659
# Epoch 9, Batch 41, Loss: 5.1822
# Epoch 9, Batch 51, Loss: 4.5991
# Epoch 9, Batch 61, Loss: 4.5580
# Epoch 9, Batch 71, Loss: 4.7064
# Epoch 9, Batch 81, Loss: 4.7121
# Epoch 10, Batch 1, Loss: 7.4251
# Epoch 10, Batch 11, Loss: 5.4278
# Epoch 10, Batch 21, Loss: 4.7843
# Epoch 10, Batch 31, Loss: 5.2030
# Epoch 10, Batch 41, Loss: 5.1230
# Epoch 10, Batch 51, Loss: 4.5465
# Epoch 10, Batch 61, Loss: 4.5078
# Epoch 10, Batch 71, Loss: 4.6555
# Epoch 10, Batch 81, Loss: 4.6629
# ------------------------embeddings_100_15_5--------------------
# 2290
# Epoch 1, Batch 1, Loss: 11.0904
# Epoch 1, Batch 11, Loss: 11.0900
# Epoch 1, Batch 21, Loss: 11.0862
# Epoch 1, Batch 31, Loss: 11.0774
# Epoch 1, Batch 41, Loss: 11.0679
# Epoch 1, Batch 51, Loss: 11.0645
# Epoch 1, Batch 61, Loss: 11.0472
# Epoch 1, Batch 71, Loss: 10.9919
# Epoch 1, Batch 81, Loss: 10.8952
# Epoch 1, Batch 91, Loss: 10.8088
# Epoch 1, Batch 101, Loss: 10.6930
# Epoch 1, Batch 111, Loss: 10.6522
# Epoch 1, Batch 121, Loss: 10.6303
# Epoch 1, Batch 131, Loss: 10.5738
# Epoch 1, Batch 141, Loss: 10.4255
# Epoch 2, Batch 1, Loss: 10.9175
# Epoch 2, Batch 11, Loss: 10.3165
# Epoch 2, Batch 21, Loss: 8.9750
# Epoch 2, Batch 31, Loss: 8.5504
# Epoch 2, Batch 41, Loss: 8.5856
# Epoch 2, Batch 51, Loss: 8.8504
# Epoch 2, Batch 61, Loss: 8.8337
# Epoch 2, Batch 71, Loss: 8.4810
# Epoch 2, Batch 81, Loss: 8.0631
# Epoch 2, Batch 91, Loss: 7.8821
# Epoch 2, Batch 101, Loss: 7.7064
# Epoch 2, Batch 111, Loss: 7.7597
# Epoch 2, Batch 121, Loss: 7.8443
# Epoch 2, Batch 131, Loss: 7.8500
# Epoch 2, Batch 141, Loss: 7.6915
# Epoch 3, Batch 1, Loss: 10.1913
# Epoch 3, Batch 11, Loss: 8.9838
# Epoch 3, Batch 21, Loss: 6.9913
# Epoch 3, Batch 31, Loss: 6.5435
# Epoch 3, Batch 41, Loss: 6.6937
# Epoch 3, Batch 51, Loss: 7.1160
# Epoch 3, Batch 61, Loss: 7.2081
# Epoch 3, Batch 71, Loss: 6.8262
# Epoch 3, Batch 81, Loss: 6.3750
# Epoch 3, Batch 91, Loss: 6.2282
# Epoch 3, Batch 101, Loss: 6.0893
# Epoch 3, Batch 111, Loss: 6.1741
# Epoch 3, Batch 121, Loss: 6.2771
# Epoch 3, Batch 131, Loss: 6.3169
# Epoch 3, Batch 141, Loss: 6.1841
# Epoch 4, Batch 1, Loss: 9.0667
# Epoch 4, Batch 11, Loss: 7.8309
# Epoch 4, Batch 21, Loss: 5.8895
# Epoch 4, Batch 31, Loss: 5.5488
# Epoch 4, Batch 41, Loss: 5.7104
# Epoch 4, Batch 51, Loss: 6.1377
# Epoch 4, Batch 61, Loss: 6.2840
# Epoch 4, Batch 71, Loss: 5.9087
# Epoch 4, Batch 81, Loss: 5.4788
# Epoch 4, Batch 91, Loss: 5.3528
# Epoch 4, Batch 101, Loss: 5.2287
# Epoch 4, Batch 111, Loss: 5.2969
# Epoch 4, Batch 121, Loss: 5.3757
# Epoch 4, Batch 131, Loss: 5.4202
# Epoch 4, Batch 141, Loss: 5.2981
# Epoch 5, Batch 1, Loss: 7.8427
# Epoch 5, Batch 11, Loss: 6.8426
# Epoch 5, Batch 21, Loss: 5.0904
# Epoch 5, Batch 31, Loss: 4.8597
# Epoch 5, Batch 41, Loss: 5.0043
# Epoch 5, Batch 51, Loss: 5.4009
# Epoch 5, Batch 61, Loss: 5.5772
# Epoch 5, Batch 71, Loss: 5.2216
# Epoch 5, Batch 81, Loss: 4.8323
# Epoch 5, Batch 91, Loss: 4.7241
# Epoch 5, Batch 101, Loss: 4.6113
# Epoch 5, Batch 111, Loss: 4.6614
# Epoch 5, Batch 121, Loss: 4.7172
# Epoch 5, Batch 131, Loss: 4.7623
# Epoch 5, Batch 141, Loss: 4.6512
# Epoch 6, Batch 1, Loss: 6.7971
# Epoch 6, Batch 11, Loss: 6.0589
# Epoch 6, Batch 21, Loss: 4.5025
# Epoch 6, Batch 31, Loss: 4.3544
# Epoch 6, Batch 41, Loss: 4.4798
# Epoch 6, Batch 51, Loss: 4.8419
# Epoch 6, Batch 61, Loss: 5.0338
# Epoch 6, Batch 71, Loss: 4.7010
# Epoch 6, Batch 81, Loss: 4.3509
# Epoch 6, Batch 91, Loss: 4.2570
# Epoch 6, Batch 101, Loss: 4.1547
# Epoch 6, Batch 111, Loss: 4.1938
# Epoch 6, Batch 121, Loss: 4.2362
# Epoch 6, Batch 131, Loss: 4.2817
# Epoch 6, Batch 141, Loss: 4.1813
# Epoch 7, Batch 1, Loss: 6.0465
# Epoch 7, Batch 11, Loss: 5.5041
# Epoch 7, Batch 21, Loss: 4.1005
# Epoch 7, Batch 31, Loss: 4.0028
# Epoch 7, Batch 41, Loss: 4.1148
# Epoch 7, Batch 51, Loss: 4.4501
# Epoch 7, Batch 61, Loss: 4.6484
# Epoch 7, Batch 71, Loss: 4.3354
# Epoch 7, Batch 81, Loss: 4.0148
# Epoch 7, Batch 91, Loss: 3.9311
# Epoch 7, Batch 101, Loss: 3.8373
# Epoch 7, Batch 111, Loss: 3.8715
# Epoch 7, Batch 121, Loss: 3.9077
# Epoch 7, Batch 131, Loss: 3.9536
# Epoch 7, Batch 141, Loss: 3.8620
# Epoch 8, Batch 1, Loss: 5.5712
# Epoch 8, Batch 11, Loss: 5.1521
# Epoch 8, Batch 21, Loss: 3.8493
# Epoch 8, Batch 31, Loss: 3.7781
# Epoch 8, Batch 41, Loss: 3.8826
# Epoch 8, Batch 51, Loss: 4.2009
# Epoch 8, Batch 61, Loss: 4.4011
# Epoch 8, Batch 71, Loss: 4.1020
# Epoch 8, Batch 81, Loss: 3.8007
# Epoch 8, Batch 91, Loss: 3.7234
# Epoch 8, Batch 101, Loss: 3.6359
# Epoch 8, Batch 111, Loss: 3.6685
# Epoch 8, Batch 121, Loss: 3.7023
# Epoch 8, Batch 131, Loss: 3.7486
# Epoch 8, Batch 141, Loss: 3.6633
# Epoch 9, Batch 1, Loss: 5.3077
# Epoch 9, Batch 11, Loss: 4.9569
# Epoch 9, Batch 21, Loss: 3.7107
# Epoch 9, Batch 31, Loss: 3.6517
# Epoch 9, Batch 41, Loss: 3.7529
# Epoch 9, Batch 51, Loss: 4.0624
# Epoch 9, Batch 61, Loss: 4.2627
# Epoch 9, Batch 71, Loss: 3.9721
# Epoch 9, Batch 81, Loss: 3.6814
# Epoch 9, Batch 91, Loss: 3.6078
# Epoch 9, Batch 101, Loss: 3.5244
# Epoch 9, Batch 111, Loss: 3.5568
# Epoch 9, Batch 121, Loss: 3.5900
# Epoch 9, Batch 131, Loss: 3.6368
# Epoch 9, Batch 141, Loss: 3.5552
# Epoch 10, Batch 1, Loss: 5.1912
# Epoch 10, Batch 11, Loss: 4.8713
# Epoch 10, Batch 21, Loss: 3.6501
# Epoch 10, Batch 31, Loss: 3.5956
# Epoch 10, Batch 41, Loss: 3.6958
# Epoch 10, Batch 51, Loss: 4.0020
# Epoch 10, Batch 61, Loss: 4.2023
# Epoch 10, Batch 71, Loss: 3.9155
# Epoch 10, Batch 81, Loss: 3.6295
# Epoch 10, Batch 91, Loss: 3.5577
# Epoch 10, Batch 101, Loss: 3.4763
# Epoch 10, Batch 111, Loss: 3.5090
# Epoch 10, Batch 121, Loss: 3.5423
# Epoch 10, Batch 131, Loss: 3.5896
# Epoch 10, Batch 141, Loss: 3.5098

# %%
from typing import List
from utils import CorpusReader
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import TruncatedSVD
from torch.utils.data import Dataset, DataLoader
import re
import gensim.downloader as api

# %% [markdown]
# ### 4. Plot and Compare Embeddings
#
# Use `sklearn.decomposition.TruncatedSVD` to reduce the dimensionality of the obtained embeddings to 2 and plot the selected words in 2D space.
#
# *Hint*:
# - Obtain the embeddings into a numpy array by `model.emb_v.cpu().data.numpy()`
# - The word2id dictionary is in `model.word2id`
# - If you are trying to load from a saved embedding file, you can use the APIs from `gensim`.
#   - For exmaple, `model = gensim.models.KeyedVectors.load_word2vec_format('path/to/file')`
#   - Check out the documentation for more details: https://radimrehurek.com/gensim/models/keyedvectors.html

# %%
# Load embeddings
### YOUR CODE HERE ###
def lsa():
    documents = []
    with open(f"lunyu_20chapters.txt", "r") as f:
        for line in f:
            documents.append(line.strip())
    documents = [document.replace(' ', '') for document in documents]
    words: str = ''.join(documents)
    vocab = Counter(words)
    print(vocab.most_common(10))
    word2index = {char: idx for idx, (char, _) in enumerate(vocab.most_common())}
    print(list(itertools.islice(word2index.items(), 10)))
    vocab_size = len(vocab) 
    num_documents = len(documents) 
    A = np.zeros((vocab_size, num_documents))
    for i, d in enumerate(documents): 
        for character in d:  
            if character in word2index: 
                w = word2index[character]  
                A[w, i] += 1  
    return A,word2index


# model = gensim.models.KeyedVectors.load_word2vec_format('path/to/file')
SkipGram_embeddings = model.emb_v.weight.detach().cpu().numpy()
word2id_skipgram= model.word2id
LSA_embeddings,word2id_lsa=lsa()
### END YOUR CODE ###
# Out:
# [('，', 1591), ('子', 972), ('。', 857), ('：', 788), ('曰', 758), ('之', 613), ('不', 583), ('也', 532), ('而', 342), ('？', 303)]
# [('，', 0), ('子', 1), ('。', 2), ('：', 3), ('曰', 4), ('之', 5), ('不', 6), ('也', 7), ('而', 8), ('？', 9)]

# %%
# Truncated SVD
### YOUR CODE HERE ###
svd = TruncatedSVD(n_components=2)
reduced_SkipGram_embeddings = svd.fit_transform(SkipGram_embeddings)
reduced_LSA_embeddings=svd.fit_transform(LSA_embeddings)
### END YOUR CODE ###

# %%
# Plot the following words or other words you are interested in
# You better pick those words that look different in the 2D space compared with the LSA vectors
target_words = ['学', '习', '曰', '子', '人', '仁']
words_pinyin = ['xue', 'xi', 'yue', 'zi', 'ren1', 'ren2']
def plot_embeddings(reduced_embeddings, words, title, word2id,save_file_name):
    plt.figure(figsize=(10, 8))
    for i,word in enumerate(words):
        if word in word2id:
            idx = word2id[word]
            plt.scatter(reduced_embeddings[idx, 0], reduced_embeddings[idx, 1], label=words_pinyin[i])
            plt.text(reduced_embeddings[idx, 0], reduced_embeddings[idx, 1], words_pinyin[i])

    plt.xlabel('Component 1')
    plt.ylabel('Component 2')
    plt.title(title)
    plt.savefig(save_file_name)
    plt.legend()
    plt.show()

plot_embeddings(reduced_SkipGram_embeddings, target_words, "SkipGram Embeddings", word2id_skipgram,"SkipGram_Embeddings.png")
plot_embeddings(reduced_LSA_embeddings, target_words, "LSA Embeddings", word2id_lsa,"LSA_Embeddings.png")
### END YOUR CODE ###

# %%
#load 18 embedings and plt
for emb_size, k, window_size in itertools.product(emb_sizes, k_values, window_sizes):
    model = gensim.models.KeyedVectors.load_word2vec_format(f'embeddings_{emb_size}_{k}_{window_size}.txt')
    word2id_skipgram= corpus.word2id
    svd = TruncatedSVD(n_components=2)
    reduced_SkipGram_embeddings = svd.fit_transform(SkipGram_embeddings)
    plot_embeddings(reduced_SkipGram_embeddings, target_words, "SkipGram Embeddings", word2id_skipgram,f'embeddings_{emb_size}_{k}_{window_size}.png')
